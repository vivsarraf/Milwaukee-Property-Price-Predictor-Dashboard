# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Model Creation Using Historical Sales Data from 2013 to 2023

# %% [markdown]
# ## Loading and reviewing the data

# %%
# Load the data
data = pd.read_csv('Resources/clean_property_data.csv')

# Print the columns to check for the correct column name
print(data.columns)
# Out:
# Index(['district', 'nbhd', 'style', 'extwall', 'stories', 'year_built',
#        'rooms', 'finishedsqft', 'units', 'bdrms', 'fbath', 'hbath', 'lotsize',
#        'sale_date', 'sale_price', 'sale_year', 'sale_month'],
#       dtype='object')

# %%
# Clean column names by stripping any extra spaces
data.columns = data.columns.str.strip()
# Check the cleaned column names
print(data.columns)
# Out:
# Index(['district', 'nbhd', 'style', 'extwall', 'stories', 'year_built',
#        'rooms', 'finishedsqft', 'units', 'bdrms', 'fbath', 'hbath', 'lotsize',
#        'sale_date', 'sale_price', 'sale_year', 'sale_month'],
#       dtype='object')

# %%
# Check data types for each column to see if any conversions are needed
data.info(type)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37763 entries, 0 to 37762
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   district      37763 non-null  int64
#  1   nbhd          37763 non-null  int64
#  2   style         37763 non-null  object
#  3   extwall       37763 non-null  object
#  4   stories       37763 non-null  float64
#  5   year_built    37763 non-null  int64
#  6   rooms         37763 non-null  int64
#  7   finishedsqft  37763 non-null  int64
#  8   units         37763 non-null  int64
#  9   bdrms         37763 non-null  int64
#  10  fbath         37763 non-null  int64
#  11  hbath         37763 non-null  int64
#  12  lotsize       37763 non-null  int64
#  13  sale_date     37763 non-null  object
#  14  sale_price    37763 non-null  int64
#  15  sale_year     37763 non-null  int64
#  16  sale_month    37763 non-null  int64
# dtypes: float64(1), int64(13), object(3)
# memory usage: 4.9+ MB

# %%
# Combining full bath and half bath columns into 1 to align with the property listings data
data['baths_total'] = data['fbath'] + data['hbath']
# Dropping 'fbath', and 'hbath' columns as they are not available in the property listings data
data = data.drop(columns=['fbath','hbath'])
# Check for any null values
data.isnull().sum()
# Out:
# district        0
# nbhd            0
# style           0
# extwall         0
# stories         0
# year_built      0
# rooms           0
# finishedsqft    0
# units           0
# bdrms           0
# lotsize         0
# sale_date       0
# sale_price      0
# sale_year       0
# sale_month      0
# baths_total     0
# dtype: int64

# %%
# Converting the sale date to datetime , becasue when imported here it couldn't read it as datetime
data['sale_date'] = pd.to_datetime(data['sale_date'], errors='coerce')
data.info(type)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37763 entries, 0 to 37762
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   district      37763 non-null  int64
#  1   nbhd          37763 non-null  int64
#  2   style         37763 non-null  object
#  3   extwall       37763 non-null  object
#  4   stories       37763 non-null  float64
#  5   year_built    37763 non-null  int64
#  6   rooms         37763 non-null  int64
#  7   finishedsqft  37763 non-null  int64
#  8   units         37763 non-null  int64
#  9   bdrms         37763 non-null  int64
#  10  lotsize       37763 non-null  int64
#  11  sale_date     37763 non-null  datetime64[ns]
#  12  sale_price    37763 non-null  int64
#  13  sale_year     37763 non-null  int64
#  14  sale_month    37763 non-null  int64
#  15  baths_total   37763 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(12), object(2)
# memory usage: 4.6+ MB

# %%
# Dropping saledate because it's not needed for the model. We're going to use sale-year and sale-month
data = data.drop(columns=['sale_date'])
data = data.rename(columns={'sale_year': 'year', 'sale_month':'month'})
# Sorting columns by alphabetical order
data = data.reindex(sorted(data.columns), axis=1)
data
# Out:
#        baths_total  bdrms  district         extwall  finishedsqft  lotsize  \
# 0                2      1         9  aluminum/vinyl           540     9176
# 1                1      1         2  aluminum/vinyl          1069     6600
# 2                1      1         1  aluminum/vinyl           676     6160
# 3                1      1         2            wood           960     4275
# 4                2      1         3           brick          1516     5400
# ...            ...    ...       ...             ...           ...      ...
# 37758            3     25         1  aluminum/vinyl          2067     4800
# 37759            3     25         7  aluminum/vinyl          2067     4800
# 37760            2     28         6  aluminum/vinyl          1736     5850
# 37761            2     29         6  aluminum/vinyl          2386     7200
# 37762            7     32         8           brick          7199     9525
#
#        month  nbhd  rooms  sale_price  stories                       style  \
# 0          2   600      3       57700      1.0                     cottage
# 1          2  1140      6      175000      1.0                    cape cod
# 2          8  1140      3       90000      1.0             res o/s 1 story
# 3          4  1480      5       70000      1.0                    cape cod
# 4          5  3320      7      500000      2.0              res o/s 2sty +
# ...      ...   ...    ...         ...      ...                         ...
# 37758      5  1140     45      138000      1.5                  duplex n/s
# 37759      3  1140     45      138000      1.5                  duplex n/s
# 37760      6  2930     63      115000      1.5                  duplex o/s
# 37761      2  2930     40      140000      2.0                  duplex o/s
# 37762      7  4000     62      370000      2.0  multiple residential bldgs
#
#        units  year  year_built
# 0          1  2023        1927
# 1          1  2023        1953
# 2          1  2023        1927
# 3          1  2023        1935
# 4          1  2023        1929
# ...      ...   ...         ...
# 37758      2  2023        1964
# 37759      2  2022        1964
# 37760      2  2022        1890
# 37761      2  2022        1889
# 37762      4  2022        1907
#
# [37763 rows x 15 columns]

# %% [markdown]
# ## Creating dummy data for the categorical column information

# %%
# Converting all non-numerical values to numerical category 
data_dummies = pd.get_dummies(data)
data_dummies
# Out:
#        baths_total  bdrms  district  finishedsqft  lotsize  month  nbhd  \
# 0                2      1         9           540     9176      2   600
# 1                1      1         2          1069     6600      2  1140
# 2                1      1         1           676     6160      8  1140
# 3                1      1         2           960     4275      4  1480
# 4                2      1         3          1516     5400      5  3320
# ...            ...    ...       ...           ...      ...    ...   ...
# 37758            3     25         1          2067     4800      5  1140
# 37759            3     25         7          2067     4800      3  1140
# 37760            2     28         6          1736     5850      6  2930
# 37761            2     29         6          2386     7200      2  2930
# 37762            7     32         8          7199     9525      7  4000
#
#        rooms  sale_price  stories  ...  style_ranch  style_res o/s 1 story  \
# 0          3       57700      1.0  ...        False                  False
# 1          6      175000      1.0  ...        False                  False
# 2          3       90000      1.0  ...        False                   True
# 3          5       70000      1.0  ...        False                  False
# 4          7      500000      2.0  ...        False                  False
# ...      ...         ...      ...  ...          ...                    ...
# 37758     45      138000      1.5  ...        False                  False
# 37759     45      138000      1.5  ...        False                  False
# 37760     63      115000      1.5  ...        False                  False
# 37761     40      140000      2.0  ...        False                  False
# 37762     62      370000      2.0  ...        False                  False
#
#        style_res o/s 2sty +  style_res o/s a & 1/2  style_residence o/s  \
# 0                     False                  False                False
# 1                     False                  False                False
# 2                     False                  False                False
# 3                     False                  False                False
# 4                      True                  False                False
# ...                     ...                    ...                  ...
# 37758                 False                  False                False
# 37759                 False                  False                False
# 37760                 False                  False                False
# 37761                 False                  False                False
# 37762                 False                  False                False
#
#        style_residence o/s 2sty+  style_split level  style_townhouse  \
# 0                          False              False            False
# 1                          False              False            False
# 2                          False              False            False
# 3                          False              False            False
# 4                          False              False            False
# ...                          ...                ...              ...
# 37758                      False              False            False
# 37759                      False              False            False
# 37760                      False              False            False
# 37761                      False              False            False
# 37762                      False              False            False
#
#        style_triplex  style_tudor
# 0              False        False
# 1              False        False
# 2              False        False
# 3              False        False
# 4              False        False
# ...              ...          ...
# 37758          False        False
# 37759          False        False
# 37760          False        False
# 37761          False        False
# 37762          False        False
#
# [37763 rows x 54 columns]

# %%
# Sort the columns by alphabetical order so it's easier to organize when feeding the inputs for the model
data_dummies = data_dummies.reindex(sorted(data_dummies.columns), axis=1)

# %%
# Exporting the data to use for finding the missing columns from the listings data later
data_dummies.to_csv("Resources\historicalsales-dummy-data.csv")

# %% [markdown]
# ## Defining Model Features and Creating the Training and Testing Datasets

# %%
# Creating the independent variables set by dropping the column to be used for the target feature
X = data_dummies.drop(columns=['sale_price'])
X
# Out:
#        baths_total  bdrms  district  extwall_alum/vynyl siding  \
# 0                2      1         9                      False
# 1                1      1         2                      False
# 2                1      1         1                      False
# 3                1      1         2                      False
# 4                2      1         3                      False
# ...            ...    ...       ...                        ...
# 37758            3     25         1                      False
# 37759            3     25         7                      False
# 37760            2     28         6                      False
# 37761            2     29         6                      False
# 37762            7     32         8                      False
#
#        extwall_aluminum / vinyl  extwall_aluminum/vinyl  \
# 0                         False                    True
# 1                         False                    True
# 2                         False                    True
# 3                         False                   False
# 4                         False                   False
# ...                         ...                     ...
# 37758                     False                    True
# 37759                     False                    True
# 37760                     False                    True
# 37761                     False                    True
# 37762                     False                   False
#
#        extwall_asphalt/other  extwall_block  extwall_brick  \
# 0                      False          False          False
# 1                      False          False          False
# 2                      False          False          False
# 3                      False          False          False
# 4                      False          False           True
# ...                      ...            ...            ...
# 37758                  False          False          False
# 37759                  False          False          False
# 37760                  False          False          False
# 37761                  False          False          False
# 37762                  False          False           True
#
#        extwall_fiber cement/hardiplank  ...  style_res o/s a & 1/2  \
# 0                                False  ...                  False
# 1                                False  ...                  False
# 2                                False  ...                  False
# 3                                False  ...                  False
# 4                                False  ...                  False
# ...                                ...  ...                    ...
# 37758                            False  ...                  False
# 37759                            False  ...                  False
# 37760                            False  ...                  False
# 37761                            False  ...                  False
# 37762                            False  ...                  False
#
#        style_residence o/s  style_residence o/s 2sty+  style_split level  \
# 0                    False                      False              False
# 1                    False                      False              False
# 2                    False                      False              False
# 3                    False                      False              False
# 4                    False                      False              False
# ...                    ...                        ...                ...
# 37758                False                      False              False
# 37759                False                      False              False
# 37760                False                      False              False
# 37761                False                      False              False
# 37762                False                      False              False
#
#        style_townhouse  style_triplex  style_tudor  units  year  year_built
# 0                False          False        False      1  2023        1927
# 1                False          False        False      1  2023        1953
# 2                False          False        False      1  2023        1927
# 3                False          False        False      1  2023        1935
# 4                False          False        False      1  2023        1929
# ...                ...            ...          ...    ...   ...         ...
# 37758            False          False        False      2  2023        1964
# 37759            False          False        False      2  2022        1964
# 37760            False          False        False      2  2022        1890
# 37761            False          False        False      2  2022        1889
# 37762            False          False        False      4  2022        1907
#
# [37763 rows x 53 columns]

# %%
# Creating the dependent variable set 
y = data_dummies['sale_price']
y
# Out:
# 0         57700
# 1        175000
# 2         90000
# 3         70000
# 4        500000
#           ...
# 37758    138000
# 37759    138000
# 37760    115000
# 37761    140000
# 37762    370000
# Name: sale_price, Length: 37763, dtype: int64

# %%
# Spliting data into training and testing 90/10 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Linear Regression Model

# %%
# Setting the model to linear regression 
model = LinearRegression()
# Fitting the model 
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Evaluating the coefficients for each column to see if they have any relationship with each other
coef = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])
coef
# Out:
#                                    Coefficient
# baths_total                       2.551186e+04
# bdrms                            -3.733590e+03
# district                         -2.485620e+03
# extwall_alum/vynyl siding         7.416753e+04
# extwall_aluminum / vinyl         -8.643104e+03
# extwall_aluminum/vinyl           -1.380771e+04
# extwall_asphalt/other            -2.841371e+04
# extwall_block                    -1.281762e+04
# extwall_brick                    -9.381697e+03
# extwall_fiber cement/hardiplank   6.555846e+04
# extwall_fiber-cement              9.233641e+03
# extwall_frame                    -8.082132e+03
# extwall_masonary frame           -4.322130e+04
# extwall_masonry / frame          -1.333688e+04
# extwall_masonry/frame            -7.569283e+03
# extwall_metal siding              7.816201e+03
# extwall_precast masonary          1.072767e-07
# extwall_prem wood                 6.607994e+03
# extwall_stone                    -1.357727e+04
# extwall_stucco                    4.045706e+03
# extwall_wood                     -8.578811e+03
# finishedsqft                      7.655153e+01
# lotsize                           2.974993e+00
# month                             6.284533e+02
# nbhd                              2.403417e+01
# rooms                             8.371240e+02
# stories                           1.199642e+04
# style_ap 1                        1.764683e+05
# style_bi-level                   -2.755251e+04
# style_cape cod                   -1.632332e+04
# style_colonial                   -1.997649e+04
# style_contemporary                1.545199e+05
# style_cottage                    -4.134608e+04
# style_dplx bungalow              -6.219030e+04
# style_duplex n/s                 -5.177426e+04
# style_duplex o/s                 -6.194919e+04
# style_duplex-cottage             -7.904926e+04
# style_mansion                     3.323151e+05
# style_milwaukee bungalow         -2.439940e+04
# style_multiple residential bldgs -9.366907e+04
# style_ranch                      -9.483075e+03
# style_res o/s 1 story            -1.339831e+04
# style_res o/s 2sty +              1.822225e+04
# style_res o/s a & 1/2            -2.830171e+04
# style_residence o/s              -6.075506e+03
# style_residence o/s 2sty+        -6.790859e+03
# style_split level                -1.812407e+04
# style_townhouse                  -8.960886e+04
# style_triplex                    -5.995645e+04
# style_tudor                       2.844316e+04
# units                            -4.054168e+04
# year                              9.981725e+03
# year_built                        1.567503e+02

# %%
# Ensuring X_train and y_train are in scope and convert to numeric types
X_train_numeric = sm.add_constant(X_train).astype(float)
y_train_numeric = y_train.astype(float)

# Fitting the model using statsmodels OLS
model_sm = sm.OLS(y_train_numeric, X_train_numeric).fit()

# Getting the p-values
p_values = model_sm.pvalues

# Creating a DataFrame for the coefficients and p-values
coef_pvalues = pd.DataFrame({'Coefficient': model_sm.params[1:], 'p-value': p_values[1:]})
coef_pvalues.index = X.columns
print(coef_pvalues)

# Displaying the full summary of the model
print(model_sm.summary())
# Out:
#                                    Coefficient        p-value
# baths_total                       2.551186e+04   0.000000e+00
# bdrms                            -3.733590e+03   1.810851e-19
# district                         -2.485620e+03   2.278981e-91
# extwall_alum/vynyl siding        -1.016671e+06  8.170953e-175
# extwall_aluminum / vinyl         -1.099482e+06   0.000000e+00
# extwall_aluminum/vinyl           -1.104647e+06   0.000000e+00
# extwall_asphalt/other            -1.119253e+06   0.000000e+00
# extwall_block                    -1.103657e+06   0.000000e+00
# extwall_brick                    -1.100221e+06   0.000000e+00
# extwall_fiber cement/hardiplank  -1.025281e+06   0.000000e+00
# extwall_fiber-cement             -1.081605e+06   0.000000e+00
# extwall_frame                    -1.098921e+06   0.000000e+00
# extwall_masonary frame           -1.134060e+06   1.130622e-67
# extwall_masonry / frame          -1.104176e+06   0.000000e+00
# extwall_masonry/frame            -1.098408e+06   0.000000e+00
# extwall_metal siding             -1.083023e+06   5.391240e-62
# extwall_precast masonary          1.583858e-08  4.634222e-119
# extwall_prem wood                -1.084231e+06   0.000000e+00
# extwall_stone                    -1.104416e+06   0.000000e+00
# extwall_stucco                   -1.086793e+06   0.000000e+00
# extwall_wood                     -1.099418e+06   0.000000e+00
# finishedsqft                      7.655153e+01   0.000000e+00
# lotsize                           2.974993e+00  3.445198e-193
# month                             6.284533e+02   2.548523e-08
# nbhd                              2.403417e+01   0.000000e+00
# rooms                             8.371240e+02   4.771890e-06
# stories                           1.199642e+04   7.623635e-11
# style_ap 1                       -6.298040e+05   2.220997e-22
# style_bi-level                   -8.338248e+05   0.000000e+00
# style_cape cod                   -8.225956e+05   0.000000e+00
# style_colonial                   -8.262488e+05   0.000000e+00
# style_contemporary               -6.517524e+05  8.665920e-141
# style_cottage                    -8.476184e+05   0.000000e+00
# style_dplx bungalow              -8.684626e+05   0.000000e+00
# style_duplex n/s                 -8.580466e+05   0.000000e+00
# style_duplex o/s                 -8.682215e+05   0.000000e+00
# style_duplex-cottage             -8.853216e+05   0.000000e+00
# style_mansion                    -4.739572e+05  3.657041e-136
# style_milwaukee bungalow         -8.306717e+05   0.000000e+00
# style_multiple residential bldgs -8.999414e+05   0.000000e+00
# style_ranch                      -8.157554e+05   0.000000e+00
# style_res o/s 1 story            -8.196706e+05   0.000000e+00
# style_res o/s 2sty +             -7.880501e+05   0.000000e+00
# style_res o/s a & 1/2            -8.345740e+05   0.000000e+00
# style_residence o/s              -8.123478e+05   0.000000e+00
# style_residence o/s 2sty+        -8.130632e+05   0.000000e+00
# style_split level                -8.243964e+05   0.000000e+00
# style_townhouse                  -8.958812e+05   0.000000e+00
# style_triplex                    -8.662288e+05   0.000000e+00
# style_tudor                      -7.778292e+05   0.000000e+00
# units                            -4.054168e+04   3.308505e-23
# year                              9.981725e+03   0.000000e+00
# year_built                        1.567503e+02   9.106163e-08
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             sale_price   R-squared:                       0.569
# Model:                            OLS   Adj. R-squared:                  0.569
# Method:                 Least Squares   F-statistic:                     896.7
# Date:                Wed, 12 Jun 2024   Prob (F-statistic):               0.00
# Time:                        19:05:18   Log-Likelihood:            -4.2438e+05
# No. Observations:               33986   AIC:                         8.489e+05
# Df Residuals:                   33935   BIC:                         8.493e+05
# Df Model:                          50
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                            -1.854e+07   3.89e+05    -47.647      0.000   -1.93e+07   -1.78e+07
# baths_total                       2.551e+04    655.807     38.901      0.000    2.42e+04    2.68e+04
# bdrms                            -3733.5896    413.482     -9.030      0.000   -4544.028   -2923.152
# district                         -2485.6203    122.242    -20.334      0.000   -2725.220   -2246.021
# extwall_alum/vynyl siding        -1.017e+06   3.59e+04    -28.354      0.000   -1.09e+06   -9.46e+05
# extwall_aluminum / vinyl         -1.099e+06   2.32e+04    -47.339      0.000   -1.15e+06   -1.05e+06
# extwall_aluminum/vinyl           -1.105e+06   2.36e+04    -46.752      0.000   -1.15e+06   -1.06e+06
# extwall_asphalt/other            -1.119e+06   2.37e+04    -47.316      0.000   -1.17e+06   -1.07e+06
# extwall_block                    -1.104e+06   2.38e+04    -46.322      0.000   -1.15e+06   -1.06e+06
# extwall_brick                      -1.1e+06   2.34e+04    -46.980      0.000   -1.15e+06   -1.05e+06
# extwall_fiber cement/hardiplank  -1.025e+06   2.44e+04    -42.077      0.000   -1.07e+06   -9.78e+05
# extwall_fiber-cement             -1.082e+06    2.4e+04    -45.001      0.000   -1.13e+06   -1.03e+06
# extwall_frame                    -1.099e+06   2.33e+04    -47.151      0.000   -1.14e+06   -1.05e+06
# extwall_masonary frame           -1.134e+06   6.51e+04    -17.421      0.000   -1.26e+06   -1.01e+06
# extwall_masonry / frame          -1.104e+06   2.35e+04    -47.058      0.000   -1.15e+06   -1.06e+06
# extwall_masonry/frame            -1.098e+06   2.37e+04    -46.382      0.000   -1.14e+06   -1.05e+06
# extwall_metal siding             -1.083e+06    6.5e+04    -16.649      0.000   -1.21e+06   -9.56e+05
# extwall_precast masonary          1.584e-08    6.8e-10     23.292      0.000    1.45e-08    1.72e-08
# extwall_prem wood                -1.084e+06   2.43e+04    -44.617      0.000   -1.13e+06   -1.04e+06
# extwall_stone                    -1.104e+06   2.35e+04    -47.086      0.000   -1.15e+06   -1.06e+06
# extwall_stucco                   -1.087e+06   2.36e+04    -46.123      0.000   -1.13e+06   -1.04e+06
# extwall_wood                     -1.099e+06   2.37e+04    -46.435      0.000   -1.15e+06   -1.05e+06
# finishedsqft                        76.5515      1.172     65.345      0.000      74.255      78.848
# lotsize                              2.9750      0.100     29.843      0.000       2.780       3.170
# month                              628.4533    112.803      5.571      0.000     407.355     849.551
# nbhd                                24.0342      0.370     65.040      0.000      23.310      24.758
# rooms                              837.1240    182.965      4.575      0.000     478.506    1195.742
# stories                             1.2e+04   1842.790      6.510      0.000    8384.492    1.56e+04
# style_ap 1                       -6.298e+05   6.47e+04     -9.738      0.000   -7.57e+05   -5.03e+05
# style_bi-level                   -8.338e+05   1.86e+04    -44.836      0.000    -8.7e+05   -7.97e+05
# style_cape cod                   -8.226e+05   1.73e+04    -47.479      0.000   -8.57e+05   -7.89e+05
# style_colonial                   -8.262e+05   1.74e+04    -47.584      0.000    -8.6e+05   -7.92e+05
# style_contemporary               -6.518e+05   2.57e+04    -25.380      0.000   -7.02e+05   -6.01e+05
# style_cottage                    -8.476e+05   1.74e+04    -48.846      0.000   -8.82e+05   -8.14e+05
# style_dplx bungalow              -8.685e+05   1.73e+04    -50.127      0.000   -9.02e+05   -8.35e+05
# style_duplex n/s                  -8.58e+05   1.76e+04    -48.825      0.000   -8.92e+05   -8.24e+05
# style_duplex o/s                 -8.682e+05   1.73e+04    -50.200      0.000   -9.02e+05   -8.34e+05
# style_duplex-cottage             -8.853e+05   1.77e+04    -50.111      0.000    -9.2e+05   -8.51e+05
# style_mansion                     -4.74e+05    1.9e+04    -24.950      0.000   -5.11e+05   -4.37e+05
# style_milwaukee bungalow         -8.307e+05   1.73e+04    -48.141      0.000   -8.64e+05   -7.97e+05
# style_multiple residential bldgs -8.999e+05   1.85e+04    -48.621      0.000   -9.36e+05   -8.64e+05
# style_ranch                      -8.158e+05   1.73e+04    -47.029      0.000    -8.5e+05   -7.82e+05
# style_res o/s 1 story            -8.197e+05   1.86e+04    -44.112      0.000   -8.56e+05   -7.83e+05
# style_res o/s 2sty +             -7.881e+05   1.78e+04    -44.188      0.000   -8.23e+05   -7.53e+05
# style_res o/s a & 1/2            -8.346e+05   1.73e+04    -48.208      0.000   -8.69e+05   -8.01e+05
# style_residence o/s              -8.123e+05   1.71e+04    -47.371      0.000   -8.46e+05   -7.79e+05
# style_residence o/s 2sty+        -8.131e+05   1.74e+04    -46.617      0.000   -8.47e+05   -7.79e+05
# style_split level                -8.244e+05   1.79e+04    -46.157      0.000   -8.59e+05   -7.89e+05
# style_townhouse                  -8.959e+05   1.78e+04    -50.445      0.000   -9.31e+05   -8.61e+05
# style_triplex                    -8.662e+05   1.86e+04    -46.693      0.000   -9.03e+05    -8.3e+05
# style_tudor                      -7.778e+05   1.75e+04    -44.362      0.000   -8.12e+05   -7.43e+05
# units                            -4.054e+04   4082.657     -9.930      0.000   -4.85e+04   -3.25e+04
# year                              9981.7247    210.961     47.315      0.000    9568.234    1.04e+04
# year_built                         156.7503     29.327      5.345      0.000      99.268     214.233
# ==============================================================================
# Omnibus:                    16197.190   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1082542.583
# Skew:                           1.465   Prob(JB):                         0.00
# Kurtosis:                      30.493   Cond. No.                     1.09e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.96e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Prediction with test data 
y_pred = model.predict(X_test)
# Getting mean square 
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 3831340589.057958

# %%
# Plotting graph between real and predicted values
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Values')
# plt.ylim(0, 1600000)
plt.show()

# %%
# determining accuracy score 
model.score(X_test, y_test)
# Out:
# 0.6342814932685354

# %% [markdown]
# ### Random Forest Regression Model

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Feature Importance for Random Forest
feature_importances = pd.DataFrame(model.feature_importances_, index=X.columns, columns=['importance']).sort_values('importance', ascending=False)

# Plotting feature importances
plt.figure(figsize=(12, 8))  # Increased figure size
plt.barh(feature_importances.index, feature_importances['importance'])
plt.xlabel('Feature Importance')
plt.title('Feature Importance for Random Forest Model')

# Adjust y-axis label spacing
plt.gca().invert_yaxis()  # Highest importance at the top
plt.gca().yaxis.set_tick_params(pad=5)  # Increase space between labels

plt.show()

# %%
y_pred = model.predict(X_test)
# getting mean square 
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 1596781613.3972156

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted Values')

# %%
model.score(X_test, y_test)
# Out:
# 0.8475800901398134

# %% [markdown]
# The Random Forest Regression Model provides the best performance with an accuracy of 84.76%. Therefore, we will proceed with this model for predicting the house prices in the next section.

# %% [markdown]
# # House Price Prediction on 2023 Listings Data

# %%
# Importing the proeprty listings dataset and viewing the first 5 rows
listings_data_df = pd.read_csv("Resources/original_extracted_df_MilwaukeeOnly_June12.csv")
listings_data_df.head()
# Out:
#    district  nbhd     style           extwall  stories  year_built  rooms  \
# 0         7  1680     ranch    aluminum/vinyl      1.0        1947      4
# 1         5  2080  cape cod    aluminum/vinyl      1.0        1950      4
# 2        13  4720  colonial    aluminum/vinyl      2.0        1932      5
# 3         9   240     ranch  aluminum / vinyl      1.0        1992      0
# 4        15  3000  colonial    aluminum/vinyl      2.0        2002      6
#
#    finishedsqft  lotsize  units  ...                address  zipcode  \
# 0           667   4356.0      1  ...      North 35th STREET    53216
# 1           953   4791.6      1  ...      North 78th STREET    53222
# 2          1152   8712.0      1  ...  West Bottsford AVENUE    53221
# 3          1156   7840.8      1  ...        West Eden PLACE    53220
# 4          1184   4356.0      1  ...      North 25th STREET    53205
#
#     latitude  longitude        ppsq  convertedlot  lotunit  marketestimate  \
# 0  43.095448 -87.957344  206.146927          0.10     sqft        139700.0
# 1  43.074600 -88.009514  187.827912          0.11     sqft        192900.0
# 2  42.964855 -87.954440  216.145833          0.20     sqft        259000.0
# 3  42.980330 -88.002720  125.346021          0.18     sqft        157300.0
# 4  43.056957 -87.944756  114.020270          0.10     sqft        132800.0
#
#    rentestimate   price
# 0         996.0  137500
# 1        1294.0  179000
# 2        1994.0  249000
# 3        1700.0  144900
# 4        1500.0  135000
#
# [5 rows x 24 columns]

# %%
# Reviewing the datatypes to see if any conversions are needed
listings_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   district        23 non-null     int64
#  1   nbhd            23 non-null     int64
#  2   style           23 non-null     object
#  3   extwall         23 non-null     object
#  4   stories         23 non-null     float64
#  5   year_built      23 non-null     int64
#  6   rooms           23 non-null     int64
#  7   finishedsqft    23 non-null     int64
#  8   lotsize         23 non-null     float64
#  9   units           23 non-null     int64
#  10  bdrms           23 non-null     int64
#  11  baths_total     23 non-null     int64
#  12  state           23 non-null     object
#  13  city            23 non-null     object
#  14  address         23 non-null     object
#  15  zipcode         23 non-null     int64
#  16  latitude        23 non-null     float64
#  17  longitude       23 non-null     float64
#  18  ppsq            23 non-null     float64
#  19  convertedlot    23 non-null     float64
#  20  lotunit         23 non-null     object
#  21  marketestimate  21 non-null     float64
#  22  rentestimate    21 non-null     float64
#  23  price           23 non-null     int64
# dtypes: float64(8), int64(10), object(6)
# memory usage: 4.4+ KB

# %%
# Dropping columns that are not needed for this project and confirming they have been dropped
listings_data_df = listings_data_df.drop(columns=['ppsq', 'convertedlot','lotunit','rentestimate'], axis=1)
listings_data_df.columns
# Out:
# Index(['district', 'nbhd', 'style', 'extwall', 'stories', 'year_built',
#        'rooms', 'finishedsqft', 'lotsize', 'units', 'bdrms', 'baths_total',
#        'state', 'city', 'address', 'zipcode', 'latitude', 'longitude',
#        'marketestimate', 'price'],
#       dtype='object')

# %%
# Creating copy of dataframe for showing results in interface
display_info_df = listings_data_df.copy()

# %%
# Preparing listings_data_df for input features into the model
# Setting the prediction date to June of 2024
predictions_df = listings_data_df.copy()
predictions_df = predictions_df.drop(columns=['state','city', 'address', 'zipcode', 'latitude', 'longitude', 'marketestimate','price'], axis=1)
predictions_df['year'] = 2024
predictions_df['month'] = 6
predictions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   district      23 non-null     int64
#  1   nbhd          23 non-null     int64
#  2   style         23 non-null     object
#  3   extwall       23 non-null     object
#  4   stories       23 non-null     float64
#  5   year_built    23 non-null     int64
#  6   rooms         23 non-null     int64
#  7   finishedsqft  23 non-null     int64
#  8   lotsize       23 non-null     float64
#  9   units         23 non-null     int64
#  10  bdrms         23 non-null     int64
#  11  baths_total   23 non-null     int64
#  12  year          23 non-null     int64
#  13  month         23 non-null     int64
# dtypes: float64(2), int64(10), object(2)
# memory usage: 2.6+ KB

# %%
# Converting the categorial data in 'style' and 'extwall' to dummy data columns
predictions_dummies = pd.get_dummies(predictions_df)
predictions_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   district                  23 non-null     int64
#  1   nbhd                      23 non-null     int64
#  2   stories                   23 non-null     float64
#  3   year_built                23 non-null     int64
#  4   rooms                     23 non-null     int64
#  5   finishedsqft              23 non-null     int64
#  6   lotsize                   23 non-null     float64
#  7   units                     23 non-null     int64
#  8   bdrms                     23 non-null     int64
#  9   baths_total               23 non-null     int64
#  10  year                      23 non-null     int64
#  11  month                     23 non-null     int64
#  12  style_bi-level            23 non-null     bool
#  13  style_cape cod            23 non-null     bool
#  14  style_colonial            23 non-null     bool
#  15  style_dplx bungalow       23 non-null     bool
#  16  style_duplex n/s          23 non-null     bool
#  17  style_duplex o/s          23 non-null     bool
#  18  style_milwaukee bungalow  23 non-null     bool
#  19  style_ranch               23 non-null     bool
#  20  style_triplex             23 non-null     bool
#  21  extwall_aluminum / vinyl  23 non-null     bool
#  22  extwall_aluminum/vinyl    23 non-null     bool
#  23  extwall_brick             23 non-null     bool
#  24  extwall_stone             23 non-null     bool
#  25  extwall_wood              23 non-null     bool
# dtypes: bool(14), float64(2), int64(10)
# memory usage: 2.6 KB

# %%
# Exporting to compare against the historical sales dummy data to find the missing columns in the listings dummy data
predictions_dummies.to_csv("Resources\listings-dummy-data.csv")

# %%
# Fill in the missing columns from the historical sales dummy data and confirm that the current number of columns is present (52)
missing_columns = ['extwall_alum/vynyl siding','extwall_asphalt/other','extwall_block','extwall_fiber cement/hardiplank','extwall_fiber-cement','extwall_frame','extwall_masonary frame','extwall_masonry / frame','extwall_masonry/frame','extwall_metal siding','extwall_precast masonary','extwall_prem wood','extwall_stucco','style_ap 1','style_contemporary','style_cottage','style_duplex-cottage','style_mansion','style_multiple residential bldgs','style_res o/s 1 story','style_res o/s 2sty +','style_res o/s a & 1/2','style_residence o/s','style_residence o/s 2sty+','style_townhouse','style_split level','style_tudor']
for col in missing_columns:
    predictions_dummies[col] = False
predictions_dummies.head()
# Out:
#    district  nbhd  stories  year_built  rooms  finishedsqft  lotsize  units  \
# 0         7  1680      1.0        1947      4           667   4356.0      1
# 1         5  2080      1.0        1950      4           953   4791.6      1
# 2        13  4720      2.0        1932      5          1152   8712.0      1
# 3         9   240      1.0        1992      0          1156   7840.8      1
# 4        15  3000      2.0        2002      6          1184   4356.0      1
#
#    bdrms  baths_total  ...  style_mansion  style_multiple residential bldgs  \
# 0      2            1  ...          False                             False
# 1      2            1  ...          False                             False
# 2      3            2  ...          False                             False
# 3      3            1  ...          False                             False
# 4      3            2  ...          False                             False
#
#    style_res o/s 1 story  style_res o/s 2sty +  style_res o/s a & 1/2  \
# 0                  False                 False                  False
# 1                  False                 False                  False
# 2                  False                 False                  False
# 3                  False                 False                  False
# 4                  False                 False                  False
#
#    style_residence o/s  style_residence o/s 2sty+  style_townhouse  \
# 0                False                      False            False
# 1                False                      False            False
# 2                False                      False            False
# 3                False                      False            False
# 4                False                      False            False
#
#    style_split level  style_tudor
# 0              False        False
# 1              False        False
# 2              False        False
# 3              False        False
# 4              False        False
#
# [5 rows x 53 columns]

# %%
# Sort the columns in alphabetical order to align with the input features order of the random forest regression model
predictions_dummies = predictions_dummies.reindex(sorted(predictions_dummies.columns), axis=1)
predictions_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 53 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   baths_total                       23 non-null     int64
#  1   bdrms                             23 non-null     int64
#  2   district                          23 non-null     int64
#  3   extwall_alum/vynyl siding         23 non-null     bool
#  4   extwall_aluminum / vinyl          23 non-null     bool
#  5   extwall_aluminum/vinyl            23 non-null     bool
#  6   extwall_asphalt/other             23 non-null     bool
#  7   extwall_block                     23 non-null     bool
#  8   extwall_brick                     23 non-null     bool
#  9   extwall_fiber cement/hardiplank   23 non-null     bool
#  10  extwall_fiber-cement              23 non-null     bool
#  11  extwall_frame                     23 non-null     bool
#  12  extwall_masonary frame            23 non-null     bool
#  13  extwall_masonry / frame           23 non-null     bool
#  14  extwall_masonry/frame             23 non-null     bool
#  15  extwall_metal siding              23 non-null     bool
#  16  extwall_precast masonary          23 non-null     bool
#  17  extwall_prem wood                 23 non-null     bool
#  18  extwall_stone                     23 non-null     bool
#  19  extwall_stucco                    23 non-null     bool
#  20  extwall_wood                      23 non-null     bool
#  21  finishedsqft                      23 non-null     int64
#  22  lotsize                           23 non-null     float64
#  23  month                             23 non-null     int64
#  24  nbhd                              23 non-null     int64
#  25  rooms                             23 non-null     int64
#  26  stories                           23 non-null     float64
#  27  style_ap 1                        23 non-null     bool
#  28  style_bi-level                    23 non-null     bool
#  29  style_cape cod                    23 non-null     bool
#  30  style_colonial                    23 non-null     bool
#  31  style_contemporary                23 non-null     bool
#  32  style_cottage                     23 non-null     bool
#  33  style_dplx bungalow               23 non-null     bool
#  34  style_duplex n/s                  23 non-null     bool
#  35  style_duplex o/s                  23 non-null     bool
#  36  style_duplex-cottage              23 non-null     bool
#  37  style_mansion                     23 non-null     bool
#  38  style_milwaukee bungalow          23 non-null     bool
#  39  style_multiple residential bldgs  23 non-null     bool
#  40  style_ranch                       23 non-null     bool
#  41  style_res o/s 1 story             23 non-null     bool
#  42  style_res o/s 2sty +              23 non-null     bool
#  43  style_res o/s a & 1/2             23 non-null     bool
#  44  style_residence o/s               23 non-null     bool
#  45  style_residence o/s 2sty+         23 non-null     bool
#  46  style_split level                 23 non-null     bool
#  47  style_townhouse                   23 non-null     bool
#  48  style_triplex                     23 non-null     bool
#  49  style_tudor                       23 non-null     bool
#  50  units                             23 non-null     int64
#  51  year                              23 non-null     int64
#  52  year_built                        23 non-null     int64
# dtypes: bool(41), float64(2), int64(10)
# memory usage: 3.2 KB

# %%
# Create a copy of the predcition dummy data and run the model to get the 2024 house price predictions for the properties in the listings data
# Store the predictions in a new column in the display_info_df dataframe
X_pred1 = predictions_dummies.copy()
y_pred1 = model.predict(X_pred1)
display_info_df['2024 predictions'] = y_pred1
display_info_df['Price difference'] = display_info_df['2024 predictions'] - display_info_df['price'] 

# X_pred2 = predictions_dummies.copy()
# X_pred2['year']=2026
# y_pred2 = model.predict(X_pred2)
# display_info_df['2026 predictions'] = y_pred2

# X_pred3 = predictions_dummies.copy()
# X_pred3['year']=2028
# y_pred3 = model.predict(X_pred3)
# display_info_df['2028 predictions'] = y_pred3

display_info_df
# Out:
#     district  nbhd               style           extwall  stories  year_built  \
# 0          7  1680               ranch    aluminum/vinyl      1.0        1947
# 1          5  2080            cape cod    aluminum/vinyl      1.0        1950
# 2         13  4720            colonial    aluminum/vinyl      2.0        1932
# 3          9   240               ranch  aluminum / vinyl      1.0        1992
# 4         15  3000            colonial    aluminum/vinyl      2.0        2002
# 5         10  2720  milwaukee bungalow    aluminum/vinyl      1.0        1926
# 6          1   900               ranch             stone      1.0        1954
# 7         13  4520            colonial    aluminum/vinyl      2.0        1948
# 8          7  1440  milwaukee bungalow    aluminum/vinyl      1.0        1929
# 9         13  4800               ranch  aluminum / vinyl      1.0        1969
# 10         5   780               ranch             brick      1.0        1977
# 11        10  1850            cape cod    aluminum/vinyl      1.5        1938
# 12        14  4910          duplex o/s    aluminum/vinyl      1.5        1910
# 13        10  2660            cape cod              wood      1.5        1953
# 14         9   480            colonial    aluminum/vinyl      2.0        1974
# 15         9   440            bi-level              wood      1.0        1976
# 16        14  4600  milwaukee bungalow  aluminum / vinyl      1.0        1924
# 17        10  2600  milwaukee bungalow    aluminum/vinyl      1.0        1916
# 18        13  4520       dplx bungalow    aluminum/vinyl      1.5        1928
# 19         2  1490          duplex n/s    aluminum/vinyl      2.0        1956
# 20         3  3320            cape cod             brick      1.0        1961
# 21         9   240            cape cod    aluminum/vinyl      1.5        2001
# 22         7  1150             triplex             brick      2.0        1958
#
#     rooms  finishedsqft  lotsize  units  ...  state       city  \
# 0       4           667   4356.0      1  ...     WI  Milwaukee
# 1       4           953   4791.6      1  ...     WI  Milwaukee
# 2       5          1152   8712.0      1  ...     WI  Milwaukee
# 3       0          1156   7840.8      1  ...     WI  Milwaukee
# 4       6          1184   4356.0      1  ...     WI  Milwaukee
# 5       7          1234   4791.6      1  ...     WI  Milwaukee
# 6       5          1271   7840.8      1  ...     WI  Milwaukee
# 7       6          1300   4356.0      1  ...     WI  Milwaukee
# 8       7          1400   3484.8      1  ...     WI  Milwaukee
# 9       0          1500  27007.2      1  ...     WI  Milwaukee
# 10      6          1506  10454.4      1  ...     WI  Milwaukee
# 11      6          1532   4791.6      1  ...     WI  Milwaukee
# 12      9          1600   3484.8      2  ...     WI  Milwaukee
# 13      6          1603   5227.2      1  ...     WI  Milwaukee
# 14      6          1717   6534.0      1  ...     WI  Milwaukee
# 15      8          1816  12196.8      1  ...     WI  Milwaukee
# 16      0          1884   5000.0      1  ...     OR  Milwaukie
# 17      9          1907  10890.0      1  ...     WI  Milwaukee
# 18     10          1972  41817.6      2  ...     WI  Milwaukee
# 19     10          2007   7840.8      2  ...     WI  Milwaukee
# 20      5          2118   5227.2      1  ...     WI  Milwaukee
# 21      6          2287  18730.8      1  ...     OR  Milwaukie
# 22     11          2739   4791.6      3  ...     WI  Milwaukee
#
#                               address zipcode   latitude   longitude  \
# 0                   North 35th STREET   53216  43.095448  -87.957344
# 1                   North 78th STREET   53222  43.074600  -88.009514
# 2               West Bottsford AVENUE   53221  42.964855  -87.954440
# 3                     West Eden PLACE   53220  42.980330  -88.002720
# 4                   North 25th STREET   53205  43.056957  -87.944756
# 5                       S Alabama Ave   53207  42.982690  -87.887985
# 6                    North 86th PLACE   53225  43.121850  -88.019295
# 7               South Whitnall AVENUE   53207  42.982292  -87.905945
# 8                    South 8th STREET   53215  42.996044  -87.921000
# 9   North Sherman BOULEVARD UNIT 4326   53216  43.095818  -87.966620
# 10                  South 83rd STREET   53220  42.980274  -88.016075
# 11                  North 45th STREET   53216  43.081413  -87.970080
# 12                  East Homer STREET   53207  42.999760  -87.899940
# 13                North Warren AVENUE   53202  43.053540  -87.893420
# 14                  North 60th STREET   53208  43.051777  -87.987220
# 15                West Good Hope ROAD   53224  43.148857  -88.034750
# 16                     SE Sellwood St   97222  45.440216 -122.628470
# 17                   North Link PLACE   53223  43.160305  -87.976050
# 18            North Sherman BOULEVARD   53216  43.077385  -87.966930
# 19               West Green Tree ROAD   53223  43.141716  -88.011400
# 20                  North 85th STREET   53222  43.072025  -88.019160
# 21                       SE Mabel Ave   97267  45.407420 -122.594246
# 22                  North 50th STREET   53216  43.076060  -87.976380
#
#     marketestimate   price  2024 predictions  Price difference
# 0         139700.0  137500          91243.50         -46256.50
# 1         192900.0  179000         205664.00          26664.00
# 2         259000.0  249000         248651.20           -348.80
# 3         157300.0  144900         171668.00          26768.00
# 4         132800.0  135000         117455.00         -17545.00
# 5         263300.0  249800         251549.00           1749.00
# 6         136300.0  135000         154220.00          19220.00
# 7         360000.0  339000         242074.00         -96926.00
# 8         156700.0  155000         117934.99         -37065.01
# 9              NaN  124900         209873.75          84973.75
# 10        294300.0  284900         290869.00           5969.00
# 11        183800.0  179000         188608.50           9608.50
# 12        370200.0  349900         332237.54         -17662.46
# 13        356000.0  349900         313444.01         -36455.99
# 14        334300.0  320000         200502.00        -119498.00
# 15        256800.0  249900         249392.00           -508.00
# 16             NaN  275000         273933.50          -1066.50
# 17        319100.0  309900         298546.00         -11354.00
# 18        162900.0  163500         259130.99          95630.99
# 19        211900.0  205000         176566.10         -28433.90
# 20        355900.0  334900         384529.33          49629.33
# 21        412700.0  399900         294380.00        -105520.00
# 22        257300.0  260000         235475.64         -24524.36
#
# [23 rows x 22 columns]

# %%
# Export the final display table for use in the final interactive dashboard
display_info_df.to_csv("Resources\/final-listings-dataset-with-predictions.csv")
