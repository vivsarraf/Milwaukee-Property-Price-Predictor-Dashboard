# %% [markdown]
# <a href="https://colab.research.google.com/github/vivsarraf/deep-learning-challenge/blob/main/Starter_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies












































































































#  Import and read the property_sales_data.csv.
import pandas as pd
property_df = pd.read_csv("Resources/property_sales_data.csv")
property_df.head()
# Out:
# C:\Users\sarra\AppData\Local\Temp\ipykernel_14376\119062455.py:9: DtypeWarning: Columns (12,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   property_df = pd.read_csv("Resources/property_sales_data.csv")
#    PropertyID     PropType    taxkey            Address CondoProject  \
# 0     98459.0   Commercial  30091000    9220 N 107TH ST          NaN
# 1     98477.0  Residential  39995000    9574 N 107TH ST          NaN
# 2     98500.0  Residential  40071000  9531 N MICHAEL CT          NaN
# 3     98566.0  Residential  50047000    9350 N JOYCE AV          NaN
# 4     98598.0  Residential  50079000  9355 N BURBANK AV          NaN
#
#    District    nbhd                      Style                  Extwall  \
# 0       9.0  6202.0  Office Building - 1 Story           Concrete Block
# 1       9.0    40.0                   Cape Cod           Aluminum/Vinyl
# 2       9.0    40.0                      Ranch  Fiber Cement/Hardiplank
# 3       9.0    40.0                      Ranch           Aluminum/Vinyl
# 4       9.0    40.0                      Ranch           Aluminum/Vinyl
#
#    Stories  Year_Built  Rooms FinishedSqft  Units  Bdrms  Fbath  Hbath  \
# 0      1.0      1981.0    NaN        12960      5    NaN    0.0    0.0
# 1      1.0      1942.0    7.0         1182      1    4.0    1.0    1.0
# 2      1.0      2006.0    9.0         1880      1    3.0    2.0    0.0
# 3      1.0      1980.0    6.0         1489      1    3.0    3.0    0.0
# 4      1.0      1986.0    5.0         1209      1    3.0    1.0    1.0
#
#   Lotsize   Sale_date Sale_price
# 0   54885  2023-08-15     530000
# 1   33541  2023-12-15     160000
# 2   10607  2023-08-31     387500
# 3    8640  2023-08-25     335000
# 4    7200  2023-06-20     250000

# %%
# Drop the non-beneficial columns
property_df = property_df.drop(columns = ['PropertyID', 'taxkey', 'CondoProject', 'District', 'nbhd', 'Style', 'Extwall', 'Stories', 'Rooms', 'Units'])
property_df
# Out:
#           PropType                 Address  Year_Built FinishedSqft  Bdrms  \
# 0       Commercial         9220 N 107TH ST      1981.0        12960    NaN
# 1      Residential         9574 N 107TH ST      1942.0         1182    4.0
# 2      Residential       9531 N MICHAEL CT      2006.0         1880    3.0
# 3      Residential         9350 N JOYCE AV      1980.0         1489    3.0
# 4      Residential       9355 N BURBANK AV      1986.0         1209    3.0
# ...            ...                     ...         ...          ...    ...
# 56227   Commercial        106 W SEEBOTH ST      1926.0         1533    0.0
# 56228   Commercial  2659 S KINNICKINNIC AV      1906.0         2880    0.0
# 56229   Commercial        417 E CHICAGO ST      1964.0        42141    0.0
# 56230   Commercial      4290 N TEUTONIA AV      1951.0        11297    0.0
# 56231  Vacant Land         6885 N 107TH ST         0.0            0    0.0
#
#        Fbath  Hbath Lotsize   Sale_date Sale_price
# 0        0.0    0.0   54885  2023-08-15     530000
# 1        1.0    1.0   33541  2023-12-15     160000
# 2        2.0    0.0   10607  2023-08-31     387500
# 3        3.0    0.0    8640  2023-08-25     335000
# 4        1.0    1.0    7200  2023-06-20     250000
# ...      ...    ...     ...         ...        ...
# 56227    0.0    0.0     421      Dec-13     203000
# 56228    0.0    0.0    3000      Dec-13     225000
# 56229    0.0    0.0   91440      Dec-13   10000000
# 56230    0.0    0.0   16403      Dec-13     200000
# 56231    0.0    0.0   20090      Dec-13      25000
#
# [56232 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
