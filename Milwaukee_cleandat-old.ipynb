# %%
# Dependencies
import pandas as pd
from pathlib import Path
from dateutil import parser
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt



from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

from sklearn.decomposition import PCA

# %%
# Store filepath in a variable
file_one = Path("Resources/Property Sales Data/2013_to_2023_property-sales-data.csv")

# %%
# Read our data file with the Pandas library
# Not every CSV requires an encoding, but be aware this can come up
original_df = pd.read_csv(file_one, encoding="ISO-8859-1")
# Out:
# C:\Users\Kunwar\AppData\Local\Temp\ipykernel_10864\2974018042.py:3: DtypeWarning: Columns (12,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   original_df = pd.read_csv(file_one, encoding="ISO-8859-1")

# %%
# Show the first five rows.
original_df.head()
# Out:
#    ï»¿PropertyID     PropType    taxkey            Address CondoProject  \
# 0        98459.0   Commercial  30091000    9220 N 107TH ST          NaN
# 1        98477.0  Residential  39995000    9574 N 107TH ST          NaN
# 2        98500.0  Residential  40071000  9531 N MICHAEL CT          NaN
# 3        98566.0  Residential  50047000    9350 N JOYCE AV          NaN
# 4        98598.0  Residential  50079000  9355 N BURBANK AV          NaN
#
#    District    nbhd                      Style                  Extwall  \
# 0       9.0  6202.0  Office Building - 1 Story           Concrete Block
# 1       9.0    40.0                   Cape Cod           Aluminum/Vinyl
# 2       9.0    40.0                      Ranch  Fiber Cement/Hardiplank
# 3       9.0    40.0                      Ranch           Aluminum/Vinyl
# 4       9.0    40.0                      Ranch           Aluminum/Vinyl
#
#    Stories  Year_Built  Rooms FinishedSqft  Units  Bdrms  Fbath  Hbath  \
# 0      1.0      1981.0    NaN        12960      5    NaN    0.0    0.0
# 1      1.0      1942.0    7.0         1182      1    4.0    1.0    1.0
# 2      1.0      2006.0    9.0         1880      1    3.0    2.0    0.0
# 3      1.0      1980.0    6.0         1489      1    3.0    3.0    0.0
# 4      1.0      1986.0    5.0         1209      1    3.0    1.0    1.0
#
#   Lotsize   Sale_date Sale_price
# 0   54885  2023-08-15     530000
# 1   33541  2023-12-15     160000
# 2   10607  2023-08-31     387500
# 3    8640  2023-08-25     335000
# 4    7200  2023-06-20     250000

# %%
#getting only 'Residential' values
residential_df = original_df.loc[original_df["PropType"] == 'Residential']
residential_df.head()
# Out:
#    ï»¿PropertyID     PropType    taxkey              Address CondoProject  \
# 1        98477.0  Residential  39995000      9574 N 107TH ST          NaN
# 2        98500.0  Residential  40071000    9531 N MICHAEL CT          NaN
# 3        98566.0  Residential  50047000      9350 N JOYCE AV          NaN
# 4        98598.0  Residential  50079000    9355 N BURBANK AV          NaN
# 5        98624.0  Residential  50105000  8210 W GLENBROOK RD          NaN
#
#    District  nbhd     Style                  Extwall  Stories  Year_Built  \
# 1       9.0  40.0  Cape Cod           Aluminum/Vinyl      1.0      1942.0
# 2       9.0  40.0     Ranch  Fiber Cement/Hardiplank      1.0      2006.0
# 3       9.0  40.0     Ranch           Aluminum/Vinyl      1.0      1980.0
# 4       9.0  40.0     Ranch           Aluminum/Vinyl      1.0      1986.0
# 5       9.0  40.0  Colonial           Aluminum/Vinyl      2.0      1989.0
#
#    Rooms FinishedSqft  Units  Bdrms  Fbath  Hbath Lotsize   Sale_date  \
# 1    7.0         1182      1    4.0    1.0    1.0   33541  2023-12-15
# 2    9.0         1880      1    3.0    2.0    0.0   10607  2023-08-31
# 3    6.0         1489      1    3.0    3.0    0.0    8640  2023-08-25
# 4    5.0         1209      1    3.0    1.0    1.0    7200  2023-06-20
# 5    6.0         1663      1    3.0    2.0    1.0    7200  2023-01-10
#
#   Sale_price
# 1     160000
# 2     387500
# 3     335000
# 4     250000
# 5     270000

# %%
#delete unwanted columns
residential_df.drop(['CondoProject', 'ï»¿PropertyID'], axis=1, inplace=True)
# Out:
# C:\Users\Kunwar\AppData\Local\Temp\ipykernel_10864\1856453742.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   residential_df.drop(['CondoProject', 'ï»¿PropertyID'], axis=1, inplace=True)

# %%
residential_df.head()
# Out:
#       PropType    taxkey              Address  District  nbhd     Style  \
# 1  Residential  39995000      9574 N 107TH ST       9.0  40.0  Cape Cod
# 2  Residential  40071000    9531 N MICHAEL CT       9.0  40.0     Ranch
# 3  Residential  50047000      9350 N JOYCE AV       9.0  40.0     Ranch
# 4  Residential  50079000    9355 N BURBANK AV       9.0  40.0     Ranch
# 5  Residential  50105000  8210 W GLENBROOK RD       9.0  40.0  Colonial
#
#                    Extwall  Stories  Year_Built  Rooms FinishedSqft  Units  \
# 1           Aluminum/Vinyl      1.0      1942.0    7.0         1182      1
# 2  Fiber Cement/Hardiplank      1.0      2006.0    9.0         1880      1
# 3           Aluminum/Vinyl      1.0      1980.0    6.0         1489      1
# 4           Aluminum/Vinyl      1.0      1986.0    5.0         1209      1
# 5           Aluminum/Vinyl      2.0      1989.0    6.0         1663      1
#
#    Bdrms  Fbath  Hbath Lotsize   Sale_date Sale_price
# 1    4.0    1.0    1.0   33541  2023-12-15     160000
# 2    3.0    2.0    0.0   10607  2023-08-31     387500
# 3    3.0    3.0    0.0    8640  2023-08-25     335000
# 4    3.0    1.0    1.0    7200  2023-06-20     250000
# 5    3.0    2.0    1.0    7200  2023-01-10     270000

# %%
residential_df.shape
# Out:
# (43742, 18)

# %%
#check datatype of each column
residential_df.dtypes
# Out:
# PropType         object
# taxkey            int64
# Address          object
# District        float64
# nbhd            float64
# Style            object
# Extwall          object
# Stories         float64
# Year_Built      float64
# Rooms           float64
# FinishedSqft     object
# Units             int64
# Bdrms           float64
# Fbath           float64
# Hbath           float64
# Lotsize          object
# Sale_date        object
# Sale_price       object
# dtype: object

# %%
# 'Sale_date' column:change the datatype format
def custom_date_parser(date_string):
    try:
        # Attempt to parse the date using dateutil.parser
        parsed_date = parser.parse(date_string, default=datetime(1, 1, 1))
        if parsed_date.year == 1:
            raise ValueError("Incomplete date, handled separately")
        return parsed_date
    except (parser.ParserError, ValueError):
        # Handle specific incomplete date cases manually
        if '-' in date_string:
            try:
                # Attempt to parse dates like "Jul-18" as month and year
                date = datetime.strptime(date_string, "%b-%y")
                return date.replace(day=1)  # Set the day to the first day of the month
            except ValueError:
                try:
                    # Attempt to parse dates like "07-18" as month and year
                    date = datetime.strptime(date_string, "%m-%y")
                    return date.replace(day=1)  # Set the day to the first day of the month
                except ValueError:
                    pass
        # Return pd.NaT if the date cannot be parsed
        return pd.NaT

# Sample data with mixed date formats
date_strings = residential_df['Sale_date']

# Apply the custom date parser to each date string
parsed_dates = [custom_date_parser(date) for date in date_strings]

# Convert to pandas Series for better handling and display
parsed_dates_series = pd.Series(parsed_dates)
print(parsed_dates_series)
# Out:
# 0       2023-12-15
# 1       2023-08-31
# 2       2023-08-25
# 3       2023-06-20
# 4       2023-01-10
#            ...
# 43737   2013-12-01
# 43738   2013-12-01
# 43739   2013-12-01
# 43740   2013-12-01
# 43741   2013-12-01
# Length: 43742, dtype: datetime64[ns]

# %%
residential_df['Sale_date']=parsed_dates_series
residential_df.head()
# Out:
# C:\Users\Kunwar\AppData\Local\Temp\ipykernel_10864\884503584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   residential_df['Sale_date']=parsed_dates_series
#       PropType    taxkey              Address  District  nbhd     Style  \
# 1  Residential  39995000      9574 N 107TH ST       9.0  40.0  Cape Cod
# 2  Residential  40071000    9531 N MICHAEL CT       9.0  40.0     Ranch
# 3  Residential  50047000      9350 N JOYCE AV       9.0  40.0     Ranch
# 4  Residential  50079000    9355 N BURBANK AV       9.0  40.0     Ranch
# 5  Residential  50105000  8210 W GLENBROOK RD       9.0  40.0  Colonial
#
#                    Extwall  Stories  Year_Built  Rooms FinishedSqft  Units  \
# 1           Aluminum/Vinyl      1.0      1942.0    7.0         1182      1
# 2  Fiber Cement/Hardiplank      1.0      2006.0    9.0         1880      1
# 3           Aluminum/Vinyl      1.0      1980.0    6.0         1489      1
# 4           Aluminum/Vinyl      1.0      1986.0    5.0         1209      1
# 5           Aluminum/Vinyl      2.0      1989.0    6.0         1663      1
#
#    Bdrms  Fbath  Hbath Lotsize  Sale_date Sale_price
# 1    4.0    1.0    1.0   33541 2023-08-31     160000
# 2    3.0    2.0    0.0   10607 2023-08-25     387500
# 3    3.0    3.0    0.0    8640 2023-06-20     335000
# 4    3.0    1.0    1.0    7200 2023-01-10     250000
# 5    3.0    2.0    1.0    7200 2023-12-27     270000

# %%
# replace '$' sign from some Sale_price values
residential_df=residential_df.dropna(subset=['Sale_price'])


residential_df['Sale_price'] = residential_df['Sale_price'].astype(str)

residential_df['Sale_price'] = residential_df['Sale_price'].str.replace('$', '')
residential_df['Sale_price'] = residential_df['Sale_price'].str.replace(',', '')
residential_df['Sale_price'] = pd.to_numeric(residential_df['Sale_price']).astype(int)
residential_df.head()
# Out:
#       PropType    taxkey              Address  District  nbhd     Style  \
# 1  Residential  39995000      9574 N 107TH ST       9.0  40.0  Cape Cod
# 2  Residential  40071000    9531 N MICHAEL CT       9.0  40.0     Ranch
# 3  Residential  50047000      9350 N JOYCE AV       9.0  40.0     Ranch
# 4  Residential  50079000    9355 N BURBANK AV       9.0  40.0     Ranch
# 5  Residential  50105000  8210 W GLENBROOK RD       9.0  40.0  Colonial
#
#                    Extwall  Stories  Year_Built  Rooms FinishedSqft  Units  \
# 1           Aluminum/Vinyl      1.0      1942.0    7.0         1182      1
# 2  Fiber Cement/Hardiplank      1.0      2006.0    9.0         1880      1
# 3           Aluminum/Vinyl      1.0      1980.0    6.0         1489      1
# 4           Aluminum/Vinyl      1.0      1986.0    5.0         1209      1
# 5           Aluminum/Vinyl      2.0      1989.0    6.0         1663      1
#
#    Bdrms  Fbath  Hbath Lotsize  Sale_date  Sale_price
# 1    4.0    1.0    1.0   33541 2023-08-31      160000
# 2    3.0    2.0    0.0   10607 2023-08-25      387500
# 3    3.0    3.0    0.0    8640 2023-06-20      335000
# 4    3.0    1.0    1.0    7200 2023-01-10      250000
# 5    3.0    2.0    1.0    7200 2023-12-27      270000

# %%
residential_df.shape
# Out:
# (43734, 18)

# %%
#try to find outliers

residential_df.describe()[['Sale_price']]
# Out:
#          Sale_price
# count  4.373400e+04
# mean   1.637099e+05
# min    0.000000e+00
# 25%    1.050000e+05
# 50%    1.499000e+05
# 75%    2.020000e+05
# max    2.500000e+06
# std    1.002268e+05

# %%
# Create the box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=residential_df['Sale_price'])
plt.title('Box Plot of Sale Prices')
plt.xlabel('Sale Price')
plt.show()

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = residential_df['Sale_price'].quantile(0.25)
Q3 = residential_df['Sale_price'].quantile(0.75)

# Calculate the IQR (Interquartile Range)
IQR = Q3 - Q1

# Calculate the lower and upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers
df_no_outliers = residential_df[(residential_df['Sale_price'] >= lower_bound) & (residential_df['Sale_price'] <= upper_bound)]


# Display the DataFrame without outliers
df_no_outliers.shape
# Out:
# (42210, 18)

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies = pd.get_dummies(residential_df)
dummies.head()
# Out:
#      taxkey  District  nbhd  Stories  Year_Built  Rooms  Units  Bdrms  Fbath  \
# 1  39995000       9.0  40.0      1.0      1942.0    7.0      1    4.0    1.0
# 2  40071000       9.0  40.0      1.0      2006.0    9.0      1    3.0    2.0
# 3  50047000       9.0  40.0      1.0      1980.0    6.0      1    3.0    3.0
# 4  50079000       9.0  40.0      1.0      1986.0    5.0      1    3.0    1.0
# 5  50105000       9.0  40.0      2.0      1989.0    6.0      1    3.0    2.0
#
#    Hbath  ... Lotsize_9956  Lotsize_9960  Lotsize_9972  Lotsize_9973  \
# 1    1.0  ...        False         False         False         False
# 2    0.0  ...        False         False         False         False
# 3    0.0  ...        False         False         False         False
# 4    1.0  ...        False         False         False         False
# 5    1.0  ...        False         False         False         False
#
#    Lotsize_9975  Lotsize_9984  Lotsize_9989  Lotsize_9990  Lotsize_9991  \
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
# 5         False         False         False         False         False
#
#    Lotsize_9999
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
#
# [5 rows x 50938 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = dummies['Sale_price'].values
X = dummies.drop(columns='Sale_price').values

pca = PCA(n_components=1)  
X_reduced = pca.fit_transform(X)


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X_reduced,y,random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Split our preprocessed data into our features and target arrays
#       2 y = dummies['Sale_price'].values
# ----> 3 X = dummies.drop(columns='Sale_price').values
#       5 pca = PCA(n_components=1)
#       6 X_reduced = pca.fit_transform(X)
#
# File c:\Users\Kunwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File c:\Users\Kunwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\Kunwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4792, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4789     new_axis = axis.take(indexer)
#    4791 bm_axis = self.ndim - axis_num - 1
# -> 4792 new_mgr = self._mgr.reindex_indexer(
#    4793     new_axis,
#    4794     indexer,
#    4795     axis=bm_axis,
#    4796     allow_dups=True,
#    4797     copy=None,
#    4798     only_slice=only_slice,
#    4799 )
#    4800 result = self._constructor_from_mgr(new_mgr, axes=new_mgr.axes)
#    4801 if self.ndim == 1:
#
# File c:\Users\Kunwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:663, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     660     raise IndexError("Requested axis not found in manager")
#     662 if axis == 0:
# --> 663     new_blocks = self._slice_take_blocks_ax0(
#     664         indexer,
#     665         fill_value=fill_value,
#     666         only_slice=only_slice,
#     667         use_na_proxy=use_na_proxy,
#     668     )
#     669 else:
#     670     new_blocks = [
#     671         blk.take_nd(
#     672             indexer,
#    (...)
#     678         for blk in self.blocks
#     679     ]
#
# File c:\Users\Kunwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:826, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy, ref_inplace_op)
#     824                     blocks.append(nb)
#     825             else:
# --> 826                 nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     827                 blocks.append(nb)
#     829 return blocks
#
# File c:\Users\Kunwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:1061, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1058     allow_fill = True
#    1060 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1061 new_values = algos.take_nd(
#    1062     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1063 )
#    1065 # Called from three places in managers, all of which satisfy
#    1066 #  these assertions
#    1067 if isinstance(self, ExtensionBlock):
#    1068     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1069     #  algos.take_nd call above.
#
# File c:\Users\Kunwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\array_algos\take.py:118, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     115     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     117 arr = np.asarray(arr)
# --> 118 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\Kunwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\array_algos\take.py:158, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     156     out = np.empty(out_shape, dtype=dtype, order="F")
#     157 else:
# --> 158     out = np.empty(out_shape, dtype=dtype)
#     160 func = _get_take_nd_function(
#     161     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162 )
#     163 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 1.49 GiB for an array with shape (36515, 43734) and data type bool

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_total = len(X_train[0])
layer1 = 80
layer2 = 30


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=layer1,input_dim = input_features_total, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2, activation="relu"))



# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=150)

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
