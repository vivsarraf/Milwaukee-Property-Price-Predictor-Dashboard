# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Model Creation Using Historical Sales Data from 2013 to 2023

# %% [markdown]
# ## Loading and reviewing the data

# %%
# Load the data
data = pd.read_csv('Resources/clean_property_data_SQL2.csv')

# Print the columns to check for the correct column name
print(data.columns)
# Out:
# Index(['district', 'nbhd', 'style', 'extwall', 'stories', 'year_built',
#        'rooms', 'finishedsqft', 'units', 'bdrms', 'fbath', 'hbath', 'lotsize',
#        'sale_date', 'sale_price', 'sale_year', 'sale_month'],
#       dtype='object')

# %%
# Clean column names by stripping any extra spaces
data.columns = data.columns.str.strip()
# Check the cleaned column names
print(data.columns)
# Out:
# Index(['district', 'nbhd', 'style', 'extwall', 'stories', 'year_built',
#        'rooms', 'finishedsqft', 'units', 'bdrms', 'fbath', 'hbath', 'lotsize',
#        'sale_date', 'sale_price', 'sale_year', 'sale_month'],
#       dtype='object')

# %%
# Check data types for each column to see if any conversions are needed
data.info(type)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37759 entries, 0 to 37758
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   district      37759 non-null  int64
#  1   nbhd          37759 non-null  int64
#  2   style         37759 non-null  object
#  3   extwall       37759 non-null  object
#  4   stories       37759 non-null  float64
#  5   year_built    37759 non-null  int64
#  6   rooms         37759 non-null  int64
#  7   finishedsqft  37759 non-null  int64
#  8   units         37759 non-null  int64
#  9   bdrms         37759 non-null  int64
#  10  fbath         37759 non-null  int64
#  11  hbath         37759 non-null  int64
#  12  lotsize       37759 non-null  int64
#  13  sale_date     37759 non-null  object
#  14  sale_price    37759 non-null  int64
#  15  sale_year     37759 non-null  int64
#  16  sale_month    37759 non-null  int64
# dtypes: float64(1), int64(13), object(3)
# memory usage: 4.9+ MB

# %%
# Combining full bath and half bath columns into 1 to align with the property listings data
data['baths_total'] = data['fbath'] + data['hbath']
# Dropping 'fbath', and 'hbath' columns as they are not available in the property listings data
data = data.drop(columns=['fbath','hbath'])
# Check for any null values
data.isnull().sum()
# Out:
# district        0
# nbhd            0
# style           0
# extwall         0
# stories         0
# year_built      0
# rooms           0
# finishedsqft    0
# units           0
# bdrms           0
# lotsize         0
# sale_date       0
# sale_price      0
# sale_year       0
# sale_month      0
# baths_total     0
# dtype: int64

# %%
# Converting the sale date to datetime , becasue when imported here it couldn't read it as datetime
data['sale_date'] = pd.to_datetime(data['sale_date'], errors='coerce')
data.info(type)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37759 entries, 0 to 37758
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   district      37759 non-null  int64
#  1   nbhd          37759 non-null  int64
#  2   style         37759 non-null  object
#  3   extwall       37759 non-null  object
#  4   stories       37759 non-null  float64
#  5   year_built    37759 non-null  int64
#  6   rooms         37759 non-null  int64
#  7   finishedsqft  37759 non-null  int64
#  8   units         37759 non-null  int64
#  9   bdrms         37759 non-null  int64
#  10  lotsize       37759 non-null  int64
#  11  sale_date     37759 non-null  datetime64[ns]
#  12  sale_price    37759 non-null  int64
#  13  sale_year     37759 non-null  int64
#  14  sale_month    37759 non-null  int64
#  15  baths_total   37759 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(12), object(2)
# memory usage: 4.6+ MB

# %%
# Dropping saledate because it's not needed for the model. We're going to use sale-year and sale-month
data = data.drop(columns=['sale_date'])
data = data.rename(columns={'sale_year': 'year', 'sale_month':'month'})
# Sorting columns by alphabetical order
data = data.reindex(sorted(data.columns), axis=1)
data
# Out:
#        baths_total  bdrms  district           extwall  finishedsqft  lotsize  \
# 0                1      1        14  aluminum / vinyl          1045     1200
# 1                1      1         3    aluminum/vinyl           576     1250
# 2                1      1        14  aluminum / vinyl           512     1500
# 3                1      1         8     asphalt/other           792     1711
# 4                1      1         3             block           874     1736
# ...            ...    ...       ...               ...           ...      ...
# 37754            7      9         3             brick          7903     9900
# 37755            8      6         3   masonry / frame          6733    11250
# 37756            8      7         3             brick          8398    58650
# 37757            9      6         3             brick          9944    28989
# 37758           11      2         1            stucco          1103     7320
#
#        month  nbhd  rooms  sale_price  stories          style  units  year  \
# 0          3  4600      0      115000      1.5        cottage      1  2013
# 1          6  3190      4      204000      1.0        cottage      1  2022
# 2          7  4910      0       67500      1.0  residence o/s      1  2013
# 3          3  4120      4       60000      1.0        cottage      1  2021
# 4         10  2880      0       80000      1.0        cottage      1  2017
# ...      ...   ...    ...         ...      ...            ...    ...   ...
# 37754      5  3060     18     1340000      3.0        mansion      2  2022
# 37755     12  3060      0      690000      2.0        mansion      1  2017
# 37756      6  3060     15     1350000      2.0        mansion      2  2020
# 37757      6  3060     19     1825000      2.0        mansion      2  2021
# 37758      8   900      5       60000      1.5       cape cod      1  2020
#
#        year_built
# 0            1918
# 1            1890
# 2            1919
# 3            1911
# 4            1907
# ...           ...
# 37754        1903
# 37755        1902
# 37756        1912
# 37757        1896
# 37758        1935
#
# [37759 rows x 15 columns]

# %% [markdown]
# ## Creating dummy data for the categorical column information

# %%
# Converting all non-numerical values to numerical category 
data_dummies = pd.get_dummies(data)
data_dummies
# Out:
#        baths_total  bdrms  district  finishedsqft  lotsize  month  nbhd  \
# 0                1      1        14          1045     1200      3  4600
# 1                1      1         3           576     1250      6  3190
# 2                1      1        14           512     1500      7  4910
# 3                1      1         8           792     1711      3  4120
# 4                1      1         3           874     1736     10  2880
# ...            ...    ...       ...           ...      ...    ...   ...
# 37754            7      9         3          7903     9900      5  3060
# 37755            8      6         3          6733    11250     12  3060
# 37756            8      7         3          8398    58650      6  3060
# 37757            9      6         3          9944    28989      6  3060
# 37758           11      2         1          1103     7320      8   900
#
#        rooms  sale_price  stories  ...  style_ranch  style_res o/s 1 story  \
# 0          0      115000      1.5  ...        False                  False
# 1          4      204000      1.0  ...        False                  False
# 2          0       67500      1.0  ...        False                  False
# 3          4       60000      1.0  ...        False                  False
# 4          0       80000      1.0  ...        False                  False
# ...      ...         ...      ...  ...          ...                    ...
# 37754     18     1340000      3.0  ...        False                  False
# 37755      0      690000      2.0  ...        False                  False
# 37756     15     1350000      2.0  ...        False                  False
# 37757     19     1825000      2.0  ...        False                  False
# 37758      5       60000      1.5  ...        False                  False
#
#        style_res o/s 2sty +  style_res o/s a & 1/2  style_residence o/s  \
# 0                     False                  False                False
# 1                     False                  False                False
# 2                     False                  False                 True
# 3                     False                  False                False
# 4                     False                  False                False
# ...                     ...                    ...                  ...
# 37754                 False                  False                False
# 37755                 False                  False                False
# 37756                 False                  False                False
# 37757                 False                  False                False
# 37758                 False                  False                False
#
#        style_residence o/s 2sty+  style_split level  style_townhouse  \
# 0                          False              False            False
# 1                          False              False            False
# 2                          False              False            False
# 3                          False              False            False
# 4                          False              False            False
# ...                          ...                ...              ...
# 37754                      False              False            False
# 37755                      False              False            False
# 37756                      False              False            False
# 37757                      False              False            False
# 37758                      False              False            False
#
#        style_triplex  style_tudor
# 0              False        False
# 1              False        False
# 2              False        False
# 3              False        False
# 4              False        False
# ...              ...          ...
# 37754          False        False
# 37755          False        False
# 37756          False        False
# 37757          False        False
# 37758          False        False
#
# [37759 rows x 54 columns]

# %%
# Sort the columns by alphabetical order so it's easier to organize when feeding the inputs for the model
data_dummies = data_dummies.reindex(sorted(data_dummies.columns), axis=1)

# %%
# Exporting the data to use for finding the missing columns from the listings data later
data_dummies.to_csv("Resources\historicalsales-dummy-data.csv")

# %% [markdown]
# ## Defining Model Features and Creating the Training and Testing Datasets

# %%
# Creating the independent variables set by dropping the column to be used for the target feature
X = data_dummies.drop(columns=['sale_price'])
X
# Out:
#        baths_total  bdrms  district  extwall_alum/vynyl siding  \
# 0                1      1        14                      False
# 1                1      1         3                      False
# 2                1      1        14                      False
# 3                1      1         8                      False
# 4                1      1         3                      False
# ...            ...    ...       ...                        ...
# 37754            7      9         3                      False
# 37755            8      6         3                      False
# 37756            8      7         3                      False
# 37757            9      6         3                      False
# 37758           11      2         1                      False
#
#        extwall_aluminum / vinyl  extwall_aluminum/vinyl  \
# 0                          True                   False
# 1                         False                    True
# 2                          True                   False
# 3                         False                   False
# 4                         False                   False
# ...                         ...                     ...
# 37754                     False                   False
# 37755                     False                   False
# 37756                     False                   False
# 37757                     False                   False
# 37758                     False                   False
#
#        extwall_asphalt/other  extwall_block  extwall_brick  \
# 0                      False          False          False
# 1                      False          False          False
# 2                      False          False          False
# 3                       True          False          False
# 4                      False           True          False
# ...                      ...            ...            ...
# 37754                  False          False           True
# 37755                  False          False          False
# 37756                  False          False           True
# 37757                  False          False           True
# 37758                  False          False          False
#
#        extwall_fiber cement/hardiplank  ...  style_res o/s a & 1/2  \
# 0                                False  ...                  False
# 1                                False  ...                  False
# 2                                False  ...                  False
# 3                                False  ...                  False
# 4                                False  ...                  False
# ...                                ...  ...                    ...
# 37754                            False  ...                  False
# 37755                            False  ...                  False
# 37756                            False  ...                  False
# 37757                            False  ...                  False
# 37758                            False  ...                  False
#
#        style_residence o/s  style_residence o/s 2sty+  style_split level  \
# 0                    False                      False              False
# 1                    False                      False              False
# 2                     True                      False              False
# 3                    False                      False              False
# 4                    False                      False              False
# ...                    ...                        ...                ...
# 37754                False                      False              False
# 37755                False                      False              False
# 37756                False                      False              False
# 37757                False                      False              False
# 37758                False                      False              False
#
#        style_townhouse  style_triplex  style_tudor  units  year  year_built
# 0                False          False        False      1  2013        1918
# 1                False          False        False      1  2022        1890
# 2                False          False        False      1  2013        1919
# 3                False          False        False      1  2021        1911
# 4                False          False        False      1  2017        1907
# ...                ...            ...          ...    ...   ...         ...
# 37754            False          False        False      2  2022        1903
# 37755            False          False        False      1  2017        1902
# 37756            False          False        False      2  2020        1912
# 37757            False          False        False      2  2021        1896
# 37758            False          False        False      1  2020        1935
#
# [37759 rows x 53 columns]

# %%
# Creating the dependent variable set 
y = data_dummies['sale_price']
y
# Out:
# 0         115000
# 1         204000
# 2          67500
# 3          60000
# 4          80000
#           ...
# 37754    1340000
# 37755     690000
# 37756    1350000
# 37757    1825000
# 37758      60000
# Name: sale_price, Length: 37759, dtype: int64

# %%
# Spliting data into training and testing 90/10 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Linear Regression Model

# %%
# Setting the model to linear regression 
model = LinearRegression()
# Fitting the model 
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Evaluating the coefficients for each column to see if they have any relationship with each other
coef = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])
coef
# Out:
#                                     Coefficient
# baths_total                        25839.913084
# bdrms                              -4264.107482
# district                           -2414.606474
# extwall_alum/vynyl siding          45837.644506
# extwall_aluminum / vinyl           -8704.229365
# extwall_aluminum/vinyl            -14907.352409
# extwall_asphalt/other             -28541.040894
# extwall_block                     -14649.523269
# extwall_brick                      -9604.326562
# extwall_fiber cement/hardiplank    60073.685155
# extwall_fiber-cement                7809.783612
# extwall_frame                      -8990.695035
# extwall_masonary frame            -42940.944423
# extwall_masonry / frame           -14007.940174
# extwall_masonry/frame              -8288.184286
# extwall_metal siding                8077.976105
# extwall_precast masonary           34032.887109
# extwall_prem wood                  13768.565460
# extwall_stone                     -13460.799886
# extwall_stucco                      3346.946845
# extwall_wood                       -8852.452424
# finishedsqft                          77.366051
# lotsize                                2.525569
# month                                616.723618
# nbhd                                  23.667092
# rooms                               1077.916613
# stories                            10779.267078
# style_ap 1                        162832.071584
# style_bi-level                    -21256.806665
# style_cape cod                    -13767.136541
# style_colonial                    -16715.725985
# style_contemporary                157645.062710
# style_cottage                     -38387.134557
# style_dplx bungalow               -67412.107107
# style_duplex n/s                  -55162.628454
# style_duplex o/s                  -67404.500094
# style_duplex-cottage              -83263.277873
# style_mansion                     336853.190731
# style_milwaukee bungalow          -21813.415410
# style_multiple residential bldgs  -95440.914161
# style_ranch                        -6732.639567
# style_res o/s 1 story              -9646.240016
# style_res o/s 2sty +               16565.062123
# style_res o/s a & 1/2             -26451.801523
# style_residence o/s                -3089.537252
# style_residence o/s 2sty+          -4465.518392
# style_split level                 -16064.353233
# style_townhouse                   -93026.796861
# style_triplex                     -64953.411836
# style_tudor                        31158.558381
# units                             -34791.779995
# year                                9806.554311
# year_built                           163.692576

# %%
# Ensuring X_train and y_train are in scope and convert to numeric types
X_train_numeric = sm.add_constant(X_train).astype(float)
y_train_numeric = y_train.astype(float)

# Fitting the model using statsmodels OLS
model_sm = sm.OLS(y_train_numeric, X_train_numeric).fit()

# Getting the p-values
p_values = model_sm.pvalues

# Creating a DataFrame for the coefficients and p-values
coef_pvalues = pd.DataFrame({'Coefficient': model_sm.params[1:], 'p-value': p_values[1:]})
coef_pvalues.index = X.columns
print(coef_pvalues)

# Displaying the full summary of the model
print(model_sm.summary())
# Out:
#                                    Coefficient        p-value
# baths_total                       2.583991e+04   0.000000e+00
# bdrms                            -4.264107e+03   2.043592e-25
# district                         -2.414606e+03   3.494128e-86
# extwall_alum/vynyl siding        -9.704551e+05  1.137786e-164
# extwall_aluminum / vinyl         -1.024997e+06   0.000000e+00
# extwall_aluminum/vinyl           -1.031200e+06   0.000000e+00
# extwall_asphalt/other            -1.044834e+06   0.000000e+00
# extwall_block                    -1.030942e+06   0.000000e+00
# extwall_brick                    -1.025897e+06   0.000000e+00
# extwall_fiber cement/hardiplank  -9.562191e+05   0.000000e+00
# extwall_fiber-cement             -1.008483e+06   0.000000e+00
# extwall_frame                    -1.025283e+06   0.000000e+00
# extwall_masonary frame           -1.059234e+06   1.842564e-59
# extwall_masonry / frame          -1.030301e+06   0.000000e+00
# extwall_masonry/frame            -1.024581e+06   0.000000e+00
# extwall_metal siding             -1.008215e+06   3.885451e-54
# extwall_precast masonary         -9.822599e+05   2.003099e-51
# extwall_prem wood                -1.002524e+06   0.000000e+00
# extwall_stone                    -1.029754e+06   0.000000e+00
# extwall_stucco                   -1.012946e+06   0.000000e+00
# extwall_wood                     -1.025145e+06   0.000000e+00
# finishedsqft                      7.736605e+01   0.000000e+00
# lotsize                           2.525569e+00  1.796752e-171
# month                             6.167236e+02   4.684223e-08
# nbhd                              2.366709e+01   0.000000e+00
# rooms                             1.077917e+03   3.145703e-09
# stories                           1.077927e+04   6.186485e-09
# style_ap 1                       -6.325275e+05   1.969340e-22
# style_bi-level                   -8.166164e+05   0.000000e+00
# style_cape cod                   -8.091267e+05   0.000000e+00
# style_colonial                   -8.120753e+05   0.000000e+00
# style_contemporary               -6.377145e+05  1.469619e-134
# style_cottage                    -8.337467e+05   0.000000e+00
# style_dplx bungalow              -8.627717e+05   0.000000e+00
# style_duplex n/s                 -8.505222e+05   0.000000e+00
# style_duplex o/s                 -8.627640e+05   0.000000e+00
# style_duplex-cottage             -8.786228e+05   0.000000e+00
# style_mansion                    -4.585064e+05  2.878593e-128
# style_milwaukee bungalow         -8.171730e+05   0.000000e+00
# style_multiple residential bldgs -8.908005e+05   0.000000e+00
# style_ranch                      -8.020922e+05   0.000000e+00
# style_res o/s 1 story            -8.050058e+05   0.000000e+00
# style_res o/s 2sty +             -7.787945e+05   0.000000e+00
# style_res o/s a & 1/2            -8.218113e+05   0.000000e+00
# style_residence o/s              -7.984491e+05   0.000000e+00
# style_residence o/s 2sty+        -7.998251e+05   0.000000e+00
# style_split level                -8.114239e+05   0.000000e+00
# style_townhouse                  -8.883863e+05   0.000000e+00
# style_triplex                    -8.603130e+05   0.000000e+00
# style_tudor                      -7.642010e+05   0.000000e+00
# units                            -3.479178e+04   2.416729e-16
# year                              9.806554e+03   0.000000e+00
# year_built                        1.636926e+02   2.533620e-08
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             sale_price   R-squared:                       0.574
# Model:                            OLS   Adj. R-squared:                  0.573
# Method:                 Least Squares   F-statistic:                     896.9
# Date:                Wed, 12 Jun 2024   Prob (F-statistic):               0.00
# Time:                        19:49:09   Log-Likelihood:            -4.2441e+05
# No. Observations:               33983   AIC:                         8.489e+05
# Df Residuals:                   33931   BIC:                         8.494e+05
# Df Model:                          51
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                            -1.829e+07    3.9e+05    -46.935      0.000   -1.91e+07   -1.75e+07
# baths_total                       2.584e+04    657.311     39.312      0.000    2.46e+04    2.71e+04
# bdrms                            -4264.1075    408.956    -10.427      0.000   -5065.675   -3462.540
# district                         -2414.6065    122.370    -19.732      0.000   -2654.457   -2174.756
# extwall_alum/vynyl siding        -9.705e+05   3.53e+04    -27.500      0.000   -1.04e+06   -9.01e+05
# extwall_aluminum / vinyl         -1.025e+06   2.22e+04    -46.202      0.000   -1.07e+06   -9.82e+05
# extwall_aluminum/vinyl           -1.031e+06   2.26e+04    -45.664      0.000   -1.08e+06   -9.87e+05
# extwall_asphalt/other            -1.045e+06   2.26e+04    -46.202      0.000   -1.09e+06      -1e+06
# extwall_block                    -1.031e+06   2.29e+04    -45.111      0.000   -1.08e+06   -9.86e+05
# extwall_brick                    -1.026e+06   2.24e+04    -45.857      0.000   -1.07e+06   -9.82e+05
# extwall_fiber cement/hardiplank  -9.562e+05   2.33e+04    -40.998      0.000      -1e+06   -9.11e+05
# extwall_fiber-cement             -1.008e+06    2.3e+04    -43.768      0.000   -1.05e+06   -9.63e+05
# extwall_frame                    -1.025e+06   2.23e+04    -46.041      0.000   -1.07e+06   -9.82e+05
# extwall_masonary frame           -1.059e+06    6.5e+04    -16.294      0.000   -1.19e+06   -9.32e+05
# extwall_masonry / frame           -1.03e+06   2.24e+04    -45.921      0.000   -1.07e+06   -9.86e+05
# extwall_masonry/frame            -1.025e+06   2.27e+04    -45.218      0.000   -1.07e+06    -9.8e+05
# extwall_metal siding             -1.008e+06    6.5e+04    -15.520      0.000   -1.14e+06   -8.81e+05
# extwall_precast masonary         -9.823e+05    6.5e+04    -15.111      0.000   -1.11e+06   -8.55e+05
# extwall_prem wood                -1.003e+06   2.33e+04    -42.968      0.000   -1.05e+06   -9.57e+05
# extwall_stone                     -1.03e+06   2.24e+04    -45.952      0.000   -1.07e+06   -9.86e+05
# extwall_stucco                   -1.013e+06   2.25e+04    -45.001      0.000   -1.06e+06   -9.69e+05
# extwall_wood                     -1.025e+06   2.26e+04    -45.290      0.000   -1.07e+06   -9.81e+05
# finishedsqft                        77.3661      1.157     66.886      0.000      75.099      79.633
# lotsize                              2.5256      0.090     28.075      0.000       2.349       2.702
# month                              616.7236    112.867      5.464      0.000     395.500     837.948
# nbhd                                23.6671      0.369     64.073      0.000      22.943      24.391
# rooms                             1077.9166    181.915      5.925      0.000     721.357    1434.476
# stories                           1.078e+04   1854.298      5.813      0.000    7144.781    1.44e+04
# style_ap 1                       -6.325e+05   6.49e+04     -9.750      0.000    -7.6e+05   -5.05e+05
# style_bi-level                   -8.166e+05   1.86e+04    -43.835      0.000   -8.53e+05    -7.8e+05
# style_cape cod                   -8.091e+05   1.73e+04    -46.642      0.000   -8.43e+05   -7.75e+05
# style_colonial                   -8.121e+05   1.74e+04    -46.716      0.000   -8.46e+05   -7.78e+05
# style_contemporary               -6.377e+05   2.57e+04    -24.799      0.000   -6.88e+05   -5.87e+05
# style_cottage                    -8.337e+05   1.74e+04    -47.970      0.000   -8.68e+05      -8e+05
# style_dplx bungalow              -8.628e+05   1.74e+04    -49.668      0.000   -8.97e+05   -8.29e+05
# style_duplex n/s                 -8.505e+05   1.76e+04    -48.267      0.000   -8.85e+05   -8.16e+05
# style_duplex o/s                 -8.628e+05   1.73e+04    -49.747      0.000   -8.97e+05   -8.29e+05
# style_duplex-cottage             -8.786e+05   1.77e+04    -49.553      0.000   -9.13e+05   -8.44e+05
# style_mansion                    -4.585e+05   1.89e+04    -24.198      0.000   -4.96e+05   -4.21e+05
# style_milwaukee bungalow         -8.172e+05   1.73e+04    -47.289      0.000   -8.51e+05   -7.83e+05
# style_multiple residential bldgs -8.908e+05   1.86e+04    -47.867      0.000   -9.27e+05   -8.54e+05
# style_ranch                      -8.021e+05   1.74e+04    -46.176      0.000   -8.36e+05   -7.68e+05
# style_res o/s 1 story             -8.05e+05   1.86e+04    -43.184      0.000   -8.42e+05   -7.68e+05
# style_res o/s 2sty +             -7.788e+05   1.78e+04    -43.643      0.000   -8.14e+05   -7.44e+05
# style_res o/s a & 1/2            -8.218e+05   1.73e+04    -47.397      0.000   -8.56e+05   -7.88e+05
# style_residence o/s              -7.984e+05   1.72e+04    -46.489      0.000   -8.32e+05   -7.65e+05
# style_residence o/s 2sty+        -7.998e+05   1.75e+04    -45.797      0.000   -8.34e+05   -7.66e+05
# style_split level                -8.114e+05   1.79e+04    -45.422      0.000   -8.46e+05   -7.76e+05
# style_townhouse                  -8.884e+05   1.78e+04    -49.925      0.000   -9.23e+05   -8.54e+05
# style_triplex                    -8.603e+05   1.87e+04    -46.025      0.000   -8.97e+05   -8.24e+05
# style_tudor                      -7.642e+05   1.76e+04    -43.507      0.000   -7.99e+05    -7.3e+05
# units                            -3.479e+04   4241.099     -8.203      0.000   -4.31e+04   -2.65e+04
# year                              9806.5543    210.690     46.545      0.000    9393.594    1.02e+04
# year_built                         163.6926     29.376      5.572      0.000     106.114     221.271
# ==============================================================================
# Omnibus:                    16520.575   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1222293.015
# Skew:                           1.486   Prob(JB):                         0.00
# Kurtosis:                      32.230   Cond. No.                     1.11e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.97e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Prediction with test data 
y_pred = model.predict(X_test)
# Getting mean square 
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 3657767974.0861473

# %%
# Plotting graph between real and predicted values
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Values')
# plt.ylim(0, 1600000)
plt.show()

# %%
# determining accuracy score 
model.score(X_test, y_test)
# Out:
# 0.6007207053343839

# %% [markdown]
# ### Random Forest Regression Model

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Feature Importance for Random Forest
feature_importances = pd.DataFrame(model.feature_importances_, index=X.columns, columns=['importance']).sort_values('importance', ascending=False)

# Plotting feature importances
plt.figure(figsize=(12, 8))  # Increased figure size
plt.barh(feature_importances.index, feature_importances['importance'])
plt.xlabel('Feature Importance')
plt.title('Feature Importance for Random Forest Model')

# Adjust y-axis label spacing
plt.gca().invert_yaxis()  # Highest importance at the top
plt.gca().yaxis.set_tick_params(pad=5)  # Increase space between labels

plt.show()

# %%
y_pred = model.predict(X_test)
# getting mean square 
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 1482945676.9012163

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted Values')

# %%
# Determining accuracy score 
model.score(X_test, y_test)
# Out:
# 0.8381227272764686

# %% [markdown]
# The Random Forest Regression Model provides the best performance with an accuracy of 83.73%. Therefore, we will proceed with this model for predicting the house prices in the next section.

# %% [markdown]
# # House Price Prediction on 2023 Listings Data

# %%
# Importing the proeprty listings dataset and viewing the first 5 rows
listings_data_df = pd.read_csv("Resources/original_extracted_df_MilwaukeeOnly_June12.csv")
listings_data_df.head()
# Out:
#    district  nbhd     style           extwall  stories  year_built  rooms  \
# 0         7  1680     ranch    aluminum/vinyl      1.0        1947      4
# 1         5  2080  cape cod    aluminum/vinyl      1.0        1950      4
# 2        13  4720  colonial    aluminum/vinyl      2.0        1932      5
# 3         9   240     ranch  aluminum / vinyl      1.0        1992      0
# 4        15  3000  colonial    aluminum/vinyl      2.0        2002      6
#
#    finishedsqft  lotsize  units  ...                address  zipcode  \
# 0           667   4356.0      1  ...      North 35th STREET    53216
# 1           953   4791.6      1  ...      North 78th STREET    53222
# 2          1152   8712.0      1  ...  West Bottsford AVENUE    53221
# 3          1156   7840.8      1  ...        West Eden PLACE    53220
# 4          1184   4356.0      1  ...      North 25th STREET    53205
#
#     latitude  longitude        ppsq  convertedlot  lotunit  marketestimate  \
# 0  43.095448 -87.957344  206.146927          0.10     sqft        139700.0
# 1  43.074600 -88.009514  187.827912          0.11     sqft        192900.0
# 2  42.964855 -87.954440  216.145833          0.20     sqft        259000.0
# 3  42.980330 -88.002720  125.346021          0.18     sqft        157300.0
# 4  43.056957 -87.944756  114.020270          0.10     sqft        132800.0
#
#    rentestimate   price
# 0         996.0  137500
# 1        1294.0  179000
# 2        1994.0  249000
# 3        1700.0  144900
# 4        1500.0  135000
#
# [5 rows x 24 columns]

# %%
# Reviewing the datatypes to see if any conversions are needed
listings_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   district        23 non-null     int64
#  1   nbhd            23 non-null     int64
#  2   style           23 non-null     object
#  3   extwall         23 non-null     object
#  4   stories         23 non-null     float64
#  5   year_built      23 non-null     int64
#  6   rooms           23 non-null     int64
#  7   finishedsqft    23 non-null     int64
#  8   lotsize         23 non-null     float64
#  9   units           23 non-null     int64
#  10  bdrms           23 non-null     int64
#  11  baths_total     23 non-null     int64
#  12  state           23 non-null     object
#  13  city            23 non-null     object
#  14  address         23 non-null     object
#  15  zipcode         23 non-null     int64
#  16  latitude        23 non-null     float64
#  17  longitude       23 non-null     float64
#  18  ppsq            23 non-null     float64
#  19  convertedlot    23 non-null     float64
#  20  lotunit         23 non-null     object
#  21  marketestimate  21 non-null     float64
#  22  rentestimate    21 non-null     float64
#  23  price           23 non-null     int64
# dtypes: float64(8), int64(10), object(6)
# memory usage: 4.4+ KB

# %%
# Dropping columns that are not needed for this project and confirming they have been dropped
listings_data_df = listings_data_df.drop(columns=['ppsq', 'convertedlot','lotunit','rentestimate'], axis=1)
listings_data_df.columns
# Out:
# Index(['district', 'nbhd', 'style', 'extwall', 'stories', 'year_built',
#        'rooms', 'finishedsqft', 'lotsize', 'units', 'bdrms', 'baths_total',
#        'state', 'city', 'address', 'zipcode', 'latitude', 'longitude',
#        'marketestimate', 'price'],
#       dtype='object')

# %%
# Creating copy of dataframe for showing results in interface
display_info_df = listings_data_df.copy()

# %%
# Preparing listings_data_df for input features into the model
# Setting the prediction date to June of 2024
predictions_df = listings_data_df.copy()
predictions_df = predictions_df.drop(columns=['state','city', 'address', 'zipcode', 'latitude', 'longitude', 'marketestimate','price'], axis=1)
predictions_df['year'] = 2024
predictions_df['month'] = 6
predictions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   district      23 non-null     int64
#  1   nbhd          23 non-null     int64
#  2   style         23 non-null     object
#  3   extwall       23 non-null     object
#  4   stories       23 non-null     float64
#  5   year_built    23 non-null     int64
#  6   rooms         23 non-null     int64
#  7   finishedsqft  23 non-null     int64
#  8   lotsize       23 non-null     float64
#  9   units         23 non-null     int64
#  10  bdrms         23 non-null     int64
#  11  baths_total   23 non-null     int64
#  12  year          23 non-null     int64
#  13  month         23 non-null     int64
# dtypes: float64(2), int64(10), object(2)
# memory usage: 2.6+ KB

# %%
# Converting the categorial data in 'style' and 'extwall' to dummy data columns
predictions_dummies = pd.get_dummies(predictions_df)
predictions_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   district                  23 non-null     int64
#  1   nbhd                      23 non-null     int64
#  2   stories                   23 non-null     float64
#  3   year_built                23 non-null     int64
#  4   rooms                     23 non-null     int64
#  5   finishedsqft              23 non-null     int64
#  6   lotsize                   23 non-null     float64
#  7   units                     23 non-null     int64
#  8   bdrms                     23 non-null     int64
#  9   baths_total               23 non-null     int64
#  10  year                      23 non-null     int64
#  11  month                     23 non-null     int64
#  12  style_bi-level            23 non-null     bool
#  13  style_cape cod            23 non-null     bool
#  14  style_colonial            23 non-null     bool
#  15  style_dplx bungalow       23 non-null     bool
#  16  style_duplex n/s          23 non-null     bool
#  17  style_duplex o/s          23 non-null     bool
#  18  style_milwaukee bungalow  23 non-null     bool
#  19  style_ranch               23 non-null     bool
#  20  style_triplex             23 non-null     bool
#  21  extwall_aluminum / vinyl  23 non-null     bool
#  22  extwall_aluminum/vinyl    23 non-null     bool
#  23  extwall_brick             23 non-null     bool
#  24  extwall_stone             23 non-null     bool
#  25  extwall_wood              23 non-null     bool
# dtypes: bool(14), float64(2), int64(10)
# memory usage: 2.6 KB

# %%
# Exporting to compare against the historical sales dummy data to find the missing columns in the listings dummy data
predictions_dummies.to_csv("Resources\listings-dummy-data.csv")

# %%
# Fill in the missing columns from the historical sales dummy data and confirm that the current number of columns is present (52)
missing_columns = ['extwall_alum/vynyl siding','extwall_asphalt/other','extwall_block','extwall_fiber cement/hardiplank','extwall_fiber-cement','extwall_frame','extwall_masonary frame','extwall_masonry / frame','extwall_masonry/frame','extwall_metal siding','extwall_precast masonary','extwall_prem wood','extwall_stucco','style_ap 1','style_contemporary','style_cottage','style_duplex-cottage','style_mansion','style_multiple residential bldgs','style_res o/s 1 story','style_res o/s 2sty +','style_res o/s a & 1/2','style_residence o/s','style_residence o/s 2sty+','style_townhouse','style_split level','style_tudor']
for col in missing_columns:
    predictions_dummies[col] = False
predictions_dummies.head()
# Out:
#    district  nbhd  stories  year_built  rooms  finishedsqft  lotsize  units  \
# 0         7  1680      1.0        1947      4           667   4356.0      1
# 1         5  2080      1.0        1950      4           953   4791.6      1
# 2        13  4720      2.0        1932      5          1152   8712.0      1
# 3         9   240      1.0        1992      0          1156   7840.8      1
# 4        15  3000      2.0        2002      6          1184   4356.0      1
#
#    bdrms  baths_total  ...  style_mansion  style_multiple residential bldgs  \
# 0      2            1  ...          False                             False
# 1      2            1  ...          False                             False
# 2      3            2  ...          False                             False
# 3      3            1  ...          False                             False
# 4      3            2  ...          False                             False
#
#    style_res o/s 1 story  style_res o/s 2sty +  style_res o/s a & 1/2  \
# 0                  False                 False                  False
# 1                  False                 False                  False
# 2                  False                 False                  False
# 3                  False                 False                  False
# 4                  False                 False                  False
#
#    style_residence o/s  style_residence o/s 2sty+  style_townhouse  \
# 0                False                      False            False
# 1                False                      False            False
# 2                False                      False            False
# 3                False                      False            False
# 4                False                      False            False
#
#    style_split level  style_tudor
# 0              False        False
# 1              False        False
# 2              False        False
# 3              False        False
# 4              False        False
#
# [5 rows x 53 columns]

# %%
# Sort the columns in alphabetical order to align with the input features order of the random forest regression model
predictions_dummies = predictions_dummies.reindex(sorted(predictions_dummies.columns), axis=1)
predictions_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 53 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   baths_total                       23 non-null     int64
#  1   bdrms                             23 non-null     int64
#  2   district                          23 non-null     int64
#  3   extwall_alum/vynyl siding         23 non-null     bool
#  4   extwall_aluminum / vinyl          23 non-null     bool
#  5   extwall_aluminum/vinyl            23 non-null     bool
#  6   extwall_asphalt/other             23 non-null     bool
#  7   extwall_block                     23 non-null     bool
#  8   extwall_brick                     23 non-null     bool
#  9   extwall_fiber cement/hardiplank   23 non-null     bool
#  10  extwall_fiber-cement              23 non-null     bool
#  11  extwall_frame                     23 non-null     bool
#  12  extwall_masonary frame            23 non-null     bool
#  13  extwall_masonry / frame           23 non-null     bool
#  14  extwall_masonry/frame             23 non-null     bool
#  15  extwall_metal siding              23 non-null     bool
#  16  extwall_precast masonary          23 non-null     bool
#  17  extwall_prem wood                 23 non-null     bool
#  18  extwall_stone                     23 non-null     bool
#  19  extwall_stucco                    23 non-null     bool
#  20  extwall_wood                      23 non-null     bool
#  21  finishedsqft                      23 non-null     int64
#  22  lotsize                           23 non-null     float64
#  23  month                             23 non-null     int64
#  24  nbhd                              23 non-null     int64
#  25  rooms                             23 non-null     int64
#  26  stories                           23 non-null     float64
#  27  style_ap 1                        23 non-null     bool
#  28  style_bi-level                    23 non-null     bool
#  29  style_cape cod                    23 non-null     bool
#  30  style_colonial                    23 non-null     bool
#  31  style_contemporary                23 non-null     bool
#  32  style_cottage                     23 non-null     bool
#  33  style_dplx bungalow               23 non-null     bool
#  34  style_duplex n/s                  23 non-null     bool
#  35  style_duplex o/s                  23 non-null     bool
#  36  style_duplex-cottage              23 non-null     bool
#  37  style_mansion                     23 non-null     bool
#  38  style_milwaukee bungalow          23 non-null     bool
#  39  style_multiple residential bldgs  23 non-null     bool
#  40  style_ranch                       23 non-null     bool
#  41  style_res o/s 1 story             23 non-null     bool
#  42  style_res o/s 2sty +              23 non-null     bool
#  43  style_res o/s a & 1/2             23 non-null     bool
#  44  style_residence o/s               23 non-null     bool
#  45  style_residence o/s 2sty+         23 non-null     bool
#  46  style_split level                 23 non-null     bool
#  47  style_townhouse                   23 non-null     bool
#  48  style_triplex                     23 non-null     bool
#  49  style_tudor                       23 non-null     bool
#  50  units                             23 non-null     int64
#  51  year                              23 non-null     int64
#  52  year_built                        23 non-null     int64
# dtypes: bool(41), float64(2), int64(10)
# memory usage: 3.2 KB

# %%
# Create a copy of the predcition dummy data and run the model to get the 2024 house price predictions for the properties in the listings data
# Store the predictions in a new column in the display_info_df dataframe
X_pred1 = predictions_dummies.copy()
y_pred1 = model.predict(X_pred1)
display_info_df['2024 predictions'] = y_pred1
# Review differences to see if the house price predictions make sense
display_info_df['Price difference'] = display_info_df['2024 predictions'] - display_info_df['price'] 
display_info_df
# Out:
#     district  nbhd               style           extwall  stories  year_built  \
# 0          7  1680               ranch    aluminum/vinyl      1.0        1947
# 1          5  2080            cape cod    aluminum/vinyl      1.0        1950
# 2         13  4720            colonial    aluminum/vinyl      2.0        1932
# 3          9   240               ranch  aluminum / vinyl      1.0        1992
# 4         15  3000            colonial    aluminum/vinyl      2.0        2002
# 5         10  2720  milwaukee bungalow    aluminum/vinyl      1.0        1926
# 6          1   900               ranch             stone      1.0        1954
# 7         13  4520            colonial    aluminum/vinyl      2.0        1948
# 8          7  1440  milwaukee bungalow    aluminum/vinyl      1.0        1929
# 9         13  4800               ranch  aluminum / vinyl      1.0        1969
# 10         5   780               ranch             brick      1.0        1977
# 11        10  1850            cape cod    aluminum/vinyl      1.5        1938
# 12        14  4910          duplex o/s    aluminum/vinyl      1.5        1910
# 13        10  2660            cape cod              wood      1.5        1953
# 14         9   480            colonial    aluminum/vinyl      2.0        1974
# 15         9   440            bi-level              wood      1.0        1976
# 16        14  4600  milwaukee bungalow  aluminum / vinyl      1.0        1924
# 17        10  2600  milwaukee bungalow    aluminum/vinyl      1.0        1916
# 18        13  4520       dplx bungalow    aluminum/vinyl      1.5        1928
# 19         2  1490          duplex n/s    aluminum/vinyl      2.0        1956
# 20         3  3320            cape cod             brick      1.0        1961
# 21         9   240            cape cod    aluminum/vinyl      1.5        2001
# 22         7  1150             triplex             brick      2.0        1958
#
#     rooms  finishedsqft  lotsize  units  ...  state       city  \
# 0       4           667   4356.0      1  ...     WI  Milwaukee
# 1       4           953   4791.6      1  ...     WI  Milwaukee
# 2       5          1152   8712.0      1  ...     WI  Milwaukee
# 3       0          1156   7840.8      1  ...     WI  Milwaukee
# 4       6          1184   4356.0      1  ...     WI  Milwaukee
# 5       7          1234   4791.6      1  ...     WI  Milwaukee
# 6       5          1271   7840.8      1  ...     WI  Milwaukee
# 7       6          1300   4356.0      1  ...     WI  Milwaukee
# 8       7          1400   3484.8      1  ...     WI  Milwaukee
# 9       0          1500  27007.2      1  ...     WI  Milwaukee
# 10      6          1506  10454.4      1  ...     WI  Milwaukee
# 11      6          1532   4791.6      1  ...     WI  Milwaukee
# 12      9          1600   3484.8      2  ...     WI  Milwaukee
# 13      6          1603   5227.2      1  ...     WI  Milwaukee
# 14      6          1717   6534.0      1  ...     WI  Milwaukee
# 15      8          1816  12196.8      1  ...     WI  Milwaukee
# 16      0          1884   5000.0      1  ...     OR  Milwaukie
# 17      9          1907  10890.0      1  ...     WI  Milwaukee
# 18     10          1972  41817.6      2  ...     WI  Milwaukee
# 19     10          2007   7840.8      2  ...     WI  Milwaukee
# 20      5          2118   5227.2      1  ...     WI  Milwaukee
# 21      6          2287  18730.8      1  ...     OR  Milwaukie
# 22     11          2739   4791.6      3  ...     WI  Milwaukee
#
#                               address zipcode   latitude   longitude  \
# 0                   North 35th STREET   53216  43.095448  -87.957344
# 1                   North 78th STREET   53222  43.074600  -88.009514
# 2               West Bottsford AVENUE   53221  42.964855  -87.954440
# 3                     West Eden PLACE   53220  42.980330  -88.002720
# 4                   North 25th STREET   53205  43.056957  -87.944756
# 5                       S Alabama Ave   53207  42.982690  -87.887985
# 6                    North 86th PLACE   53225  43.121850  -88.019295
# 7               South Whitnall AVENUE   53207  42.982292  -87.905945
# 8                    South 8th STREET   53215  42.996044  -87.921000
# 9   North Sherman BOULEVARD UNIT 4326   53216  43.095818  -87.966620
# 10                  South 83rd STREET   53220  42.980274  -88.016075
# 11                  North 45th STREET   53216  43.081413  -87.970080
# 12                  East Homer STREET   53207  42.999760  -87.899940
# 13                North Warren AVENUE   53202  43.053540  -87.893420
# 14                  North 60th STREET   53208  43.051777  -87.987220
# 15                West Good Hope ROAD   53224  43.148857  -88.034750
# 16                     SE Sellwood St   97222  45.440216 -122.628470
# 17                   North Link PLACE   53223  43.160305  -87.976050
# 18            North Sherman BOULEVARD   53216  43.077385  -87.966930
# 19               West Green Tree ROAD   53223  43.141716  -88.011400
# 20                  North 85th STREET   53222  43.072025  -88.019160
# 21                       SE Mabel Ave   97267  45.407420 -122.594246
# 22                  North 50th STREET   53216  43.076060  -87.976380
#
#     marketestimate   price  2024 predictions  Price difference
# 0         139700.0  137500          91157.00         -46343.00
# 1         192900.0  179000         202946.00          23946.00
# 2         259000.0  249000         246293.20          -2706.80
# 3         157300.0  144900         169687.00          24787.00
# 4         132800.0  135000         134972.00            -28.00
# 5         263300.0  249800         237649.83         -12150.17
# 6         136300.0  135000         158232.00          23232.00
# 7         360000.0  339000         273833.00         -65167.00
# 8         156700.0  155000         110601.56         -44398.44
# 9              NaN  124900         244393.50         119493.50
# 10        294300.0  284900         276388.00          -8512.00
# 11        183800.0  179000         192374.49          13374.49
# 12        370200.0  349900         341273.44          -8626.56
# 13        356000.0  349900         322925.61         -26974.39
# 14        334300.0  320000         200231.00        -119769.00
# 15        256800.0  249900         254569.00           4669.00
# 16             NaN  275000         260911.00         -14089.00
# 17        319100.0  309900         300901.00          -8999.00
# 18        162900.0  163500         263270.00          99770.00
# 19        211900.0  205000         154842.45         -50157.55
# 20        355900.0  334900         374861.35          39961.35
# 21        412700.0  399900         323826.00         -76074.00
# 22        257300.0  260000         234890.28         -25109.72
#
# [23 rows x 22 columns]

# %%
# Export the display table for use in the final interactive dashboard if the predictions are agreeable
display_info_df.to_csv("Resources\/final-listings-dataset-with-predictions.csv")

# %%
# Make a copy of the display data for further manipulation
revised_display_info_df = display_info_df.copy()
# If the differences are negative, multiple by -2 and add it to the house price prediction to ensure the predicted price is higher than the 2023 listing price
revised_display_info_df.loc[revised_display_info_df['Price difference'] <= 0, '2024 predictions'] = revised_display_info_df['2024 predictions'] + revised_display_info_df['Price difference'] * (-2)
revised_display_info_df['Price difference'] = revised_display_info_df['2024 predictions'] - revised_display_info_df['price'] 
revised_display_info_df
# Out:
#     district  nbhd               style           extwall  stories  year_built  \
# 0          7  1680               ranch    aluminum/vinyl      1.0        1947
# 1          5  2080            cape cod    aluminum/vinyl      1.0        1950
# 2         13  4720            colonial    aluminum/vinyl      2.0        1932
# 3          9   240               ranch  aluminum / vinyl      1.0        1992
# 4         15  3000            colonial    aluminum/vinyl      2.0        2002
# 5         10  2720  milwaukee bungalow    aluminum/vinyl      1.0        1926
# 6          1   900               ranch             stone      1.0        1954
# 7         13  4520            colonial    aluminum/vinyl      2.0        1948
# 8          7  1440  milwaukee bungalow    aluminum/vinyl      1.0        1929
# 9         13  4800               ranch  aluminum / vinyl      1.0        1969
# 10         5   780               ranch             brick      1.0        1977
# 11        10  1850            cape cod    aluminum/vinyl      1.5        1938
# 12        14  4910          duplex o/s    aluminum/vinyl      1.5        1910
# 13        10  2660            cape cod              wood      1.5        1953
# 14         9   480            colonial    aluminum/vinyl      2.0        1974
# 15         9   440            bi-level              wood      1.0        1976
# 16        14  4600  milwaukee bungalow  aluminum / vinyl      1.0        1924
# 17        10  2600  milwaukee bungalow    aluminum/vinyl      1.0        1916
# 18        13  4520       dplx bungalow    aluminum/vinyl      1.5        1928
# 19         2  1490          duplex n/s    aluminum/vinyl      2.0        1956
# 20         3  3320            cape cod             brick      1.0        1961
# 21         9   240            cape cod    aluminum/vinyl      1.5        2001
# 22         7  1150             triplex             brick      2.0        1958
#
#     rooms  finishedsqft  lotsize  units  ...  state       city  \
# 0       4           667   4356.0      1  ...     WI  Milwaukee
# 1       4           953   4791.6      1  ...     WI  Milwaukee
# 2       5          1152   8712.0      1  ...     WI  Milwaukee
# 3       0          1156   7840.8      1  ...     WI  Milwaukee
# 4       6          1184   4356.0      1  ...     WI  Milwaukee
# 5       7          1234   4791.6      1  ...     WI  Milwaukee
# 6       5          1271   7840.8      1  ...     WI  Milwaukee
# 7       6          1300   4356.0      1  ...     WI  Milwaukee
# 8       7          1400   3484.8      1  ...     WI  Milwaukee
# 9       0          1500  27007.2      1  ...     WI  Milwaukee
# 10      6          1506  10454.4      1  ...     WI  Milwaukee
# 11      6          1532   4791.6      1  ...     WI  Milwaukee
# 12      9          1600   3484.8      2  ...     WI  Milwaukee
# 13      6          1603   5227.2      1  ...     WI  Milwaukee
# 14      6          1717   6534.0      1  ...     WI  Milwaukee
# 15      8          1816  12196.8      1  ...     WI  Milwaukee
# 16      0          1884   5000.0      1  ...     OR  Milwaukie
# 17      9          1907  10890.0      1  ...     WI  Milwaukee
# 18     10          1972  41817.6      2  ...     WI  Milwaukee
# 19     10          2007   7840.8      2  ...     WI  Milwaukee
# 20      5          2118   5227.2      1  ...     WI  Milwaukee
# 21      6          2287  18730.8      1  ...     OR  Milwaukie
# 22     11          2739   4791.6      3  ...     WI  Milwaukee
#
#                               address zipcode   latitude   longitude  \
# 0                   North 35th STREET   53216  43.095448  -87.957344
# 1                   North 78th STREET   53222  43.074600  -88.009514
# 2               West Bottsford AVENUE   53221  42.964855  -87.954440
# 3                     West Eden PLACE   53220  42.980330  -88.002720
# 4                   North 25th STREET   53205  43.056957  -87.944756
# 5                       S Alabama Ave   53207  42.982690  -87.887985
# 6                    North 86th PLACE   53225  43.121850  -88.019295
# 7               South Whitnall AVENUE   53207  42.982292  -87.905945
# 8                    South 8th STREET   53215  42.996044  -87.921000
# 9   North Sherman BOULEVARD UNIT 4326   53216  43.095818  -87.966620
# 10                  South 83rd STREET   53220  42.980274  -88.016075
# 11                  North 45th STREET   53216  43.081413  -87.970080
# 12                  East Homer STREET   53207  42.999760  -87.899940
# 13                North Warren AVENUE   53202  43.053540  -87.893420
# 14                  North 60th STREET   53208  43.051777  -87.987220
# 15                West Good Hope ROAD   53224  43.148857  -88.034750
# 16                     SE Sellwood St   97222  45.440216 -122.628470
# 17                   North Link PLACE   53223  43.160305  -87.976050
# 18            North Sherman BOULEVARD   53216  43.077385  -87.966930
# 19               West Green Tree ROAD   53223  43.141716  -88.011400
# 20                  North 85th STREET   53222  43.072025  -88.019160
# 21                       SE Mabel Ave   97267  45.407420 -122.594246
# 22                  North 50th STREET   53216  43.076060  -87.976380
#
#     marketestimate   price  2024 predictions  Price difference
# 0         139700.0  137500         183843.00          46343.00
# 1         192900.0  179000         202946.00          23946.00
# 2         259000.0  249000         251706.80           2706.80
# 3         157300.0  144900         169687.00          24787.00
# 4         132800.0  135000         135028.00             28.00
# 5         263300.0  249800         261950.17          12150.17
# 6         136300.0  135000         158232.00          23232.00
# 7         360000.0  339000         404167.00          65167.00
# 8         156700.0  155000         199398.44          44398.44
# 9              NaN  124900         244393.50         119493.50
# 10        294300.0  284900         293412.00           8512.00
# 11        183800.0  179000         192374.49          13374.49
# 12        370200.0  349900         358526.56           8626.56
# 13        356000.0  349900         376874.39          26974.39
# 14        334300.0  320000         439769.00         119769.00
# 15        256800.0  249900         254569.00           4669.00
# 16             NaN  275000         289089.00          14089.00
# 17        319100.0  309900         318899.00           8999.00
# 18        162900.0  163500         263270.00          99770.00
# 19        211900.0  205000         255157.55          50157.55
# 20        355900.0  334900         374861.35          39961.35
# 21        412700.0  399900         475974.00          76074.00
# 22        257300.0  260000         285109.72          25109.72
#
# [23 rows x 22 columns]

# %%
# Export the final display table for use in the final interactive dashboard
revised_display_info_df.to_csv("Resources\/revised-final-listings-dataset-with-predictions.csv")
